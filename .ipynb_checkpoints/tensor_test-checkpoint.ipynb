# %%
# -*- coding: utf-8 -*-

# 절대 임포트 설정
from __future__ import absolute_import
from __future__ import print_function

# 필요한 라이브러리들을 임포트
import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: 필요한 데이터를 다운로드한다.
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """파일이 존재하지 않으면 다운로드하고 사이즈가 적절한지 체크한다."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)

# 문자열로 데이터를 읽는다
def read_data(filename):
  """zip파일 압축을 해제하고 단어들의 리스트를 읽는다."""
  with zipfile.ZipFile(filename) as f:
    data = f.read(f.namelist()[0]).split()
  return data

words = read_data(filename)
print('Data size', len(words))

# Step 2: dictionary를 만들고 UNK 토큰을 이용해서 rare words를 교체(replace)한다.
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0

# Step 3: skip-gram model을 위한 트레이닝 데이터(batch)를 생성하기 위한 함수.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
      '->', labels[i, 0], reverse_dictionary[labels[i, 0]])

# Step 4: skip-gram model 만들고 학습시킨다.

batch_size = 128
embedding_size = 128  # embedding vector의 크기.
skip_window = 1       # 윈도우 크기 : 왼쪽과 오른쪽으로 얼마나 많은 단어를 고려할지를 결정.
num_skips = 2         # 레이블(label)을 생성하기 위해 인풋을 얼마나 많이 재사용 할 것인지를 결정.

# sample에 대한 validation set은 원래 랜덤하게 선택해야한다. 하지만 여기서는 validation samples을 
# 가장 자주 생성되고 낮은 숫자의 ID를 가진 단어로 제한한다.
valid_size = 16     # validation 사이즈.
valid_window = 100  # 분포의 앞부분(head of the distribution)에서만 validation sample을 선택한다.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # sample에 대한 negative examples의 개수.

graph = tf.Graph()

with graph.as_default():

  # 트레이닝을 위한 인풋 데이터들
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # embedding vectors 행렬을 랜덤값으로 초기화
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    # 행렬에 트레이닝 데이터를 지정
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # NCE loss를 위한 변수들을 선언
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # batch의 average NCE loss를 계산한다.
  # tf.nce_loss 함수는 loss를 평가(evaluate)할 때마다 negative labels을 가진 새로운 샘플을 자동적으로 생성한다.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # SGD optimizer를 생성한다.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # minibatch examples과 모든 embeddings에 대해 cosine similarity를 계산한다.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

# Step 5: 트레이닝을 시작한다.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # 트레이닝을 시작하기 전에 모든 변수들을 초기화한다.
  tf.initialize_all_variables().run()
  print("Initialized")

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

    # optimizer op을 평가(evaluating)하면서 한 스텝 업데이트를 진행한다.
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # 평균 손실(average loss)은 지난 2000 배치의 손실(loss)로부터 측정된다.
      print("Average loss at step ", step, ": ", average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # nearest neighbors의 개수
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log_str = "Nearest to %s:" % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = "%s %s," % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

# Step 6: embeddings을 시각화한다.

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print("Please install sklearn and matplotlib to visualize embeddings.")
# Out:
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], (b'the', 1061396), (b'of', 593677), (b'and', 416629), (b'one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] [b'anarchism', b'originated', b'as', b'a', b'term', b'of', b'abuse', b'first', b'used', b'against']
# 3081 b'originated' -> 12 b'as'
# 3081 b'originated' -> 5234 b'anarchism'
# 12 b'as' -> 6 b'a'
# 12 b'as' -> 3081 b'originated'
# 6 b'a' -> 195 b'term'
# 6 b'a' -> 12 b'as'
# 195 b'term' -> 2 b'of'
# 195 b'term' -> 6 b'a'
# WARNING:tensorflow:From C:\Users\user\Anaconda3\lib\site-packages\tensorflow\python\util\tf_should_use.py:107: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step  0 :  308.433746338
# Nearest to b'some': b'subtly', b'dimer', b'staffs', b'nhk', b'subkey', b'apeiron', b'bundle', b'earls',
# Nearest to b'but': b'smaller', b'confessions', b'location', b'stewart', b'legendary', b'alongside', b'systematic', b'sabina',
# Nearest to b'not': b'nmt', b'wei', b'handhelds', b'css', b'mbta', b'brimstone', b'voles', b'envelope',
# Nearest to b'this': b'montreux', b'downturn', b'subsumed', b'disembodied', b'inner', b'whiskers', b'prosperous', b'manchester',
# Nearest to b'are': b'cauchy', b'albornoz', b'epithets', b'diversion', b'informed', b'pebble', b'throne', b'guinevere',
# Nearest to b'has': b'disguised', b'debra', b'remo', b'macrostate', b'backside', b'visor', b'uucp', b'burrow',
# Nearest to b'six': b'aromatic', b'evils', b'famicom', b'roundly', b'carniola', b'ceylon', b'plaster', b'apocalypse',
# Nearest to b'i': b'faltered', b'irritating', b'mojo', b'emmanuel', b'putatively', b'mdi', b'mcgregor', b'remini',
# Nearest to b'war': b'larnaca', b'develop', b'writes', b'nr', b'portrait', b'fellowships', b'unfairly', b'abnormally',
# Nearest to b'will': b'cosa', b'sappho', b'schooling', b'dried', b'kowtow', b'lifetimes', b'foundation', b'martov',
# Nearest to b'would': b'bem', b'lexus', b'carmelite', b'rostock', b'chapel', b'gdp', b'clone', b'wenham',
# Nearest to b'if': b'quincy', b'eris', b'wt', b'veto', b'wasting', b'golfers', b'scotia', b'diphtheria',
# Nearest to b'to': b'pianist', b'dimensions', b'icosahedron', b'vocation', b'angers', b'messages', b'mingle', b'eml',
# Nearest to b'see': b'grapple', b'heat', b'deo', b'mvs', b'chakra', b'quenched', b'gout', b'thummim',
# Nearest to b'had': b'hui', b'orbited', b'gora', b'tactician', b'korzybski', b'queer', b'probing', b'alaskans',
# Nearest to b'only': b'donkeys', b'rebranded', b'alkene', b'mastermind', b'lakshadweep', b'imbalance', b'devolution', b'alas',
# Average loss at step  2000 :  113.381693092
# Average loss at step  4000 :  52.7562213826
# Average loss at step  6000 :  33.2915540159
# Average loss at step  8000 :  23.8489529541
# Average loss at step  10000 :  17.8666842541
# Nearest to b'some': b'victoriae', b'publisher', b'nhk', b'held', b'austin', b'developments', b'compete', b'archie',
# Nearest to b'but': b'and', b'alongside', b'victoriae', b'smaller', b'location', b'amo', b'linebackers', b'legendary',
# Nearest to b'not': b'also', b'to', b'envelope', b'differ', b'victoriae', b'aa', b'could', b'william',
# Nearest to b'this': b'inner', b'the', b'it', b'vs', b'agave', b'technology', b'cavalry', b'gets',
# Nearest to b'are': b'is', b'informed', b'urdu', b'and', b'nasa', b'in', b'horsepower', b'throne',
# Nearest to b'has': b'is', b'agave', b'asserts', b'long', b'kinds', b'was', b'absolute', b'civilians',
# Nearest to b'six': b'zero', b'nine', b'austin', b'gland', b'victoriae', b'basins', b'amo', b'phi',
# Nearest to b'i': b'bordered', b'recruiting', b'phi', b'he', b'aqua', b'took', b'fisher', b'nuremberg',
# Nearest to b'war': b'portrait', b'bed', b'innocent', b'austin', b'stamp', b'spend', b'develop', b'gland',
# Nearest to b'will': b'dried', b'stylization', b'fao', b'vary', b'foundation', b'surname', b'dense', b'asceticism',
# Nearest to b'would': b'ground', b'anglicanism', b'to', b'aol', b'windows', b'slave', b'off', b'suffix',
# Nearest to b'if': b'theism', b'tao', b'resolution', b'source', b'directors', b'appearances', b'composer', b'possibly',
# Nearest to b'to': b'and', b'in', b'bar', b'nixon', b'not', b'ground', b'flights', b'of',
# Nearest to b'see': b'heat', b'yardage', b'editor', b'grapple', b'two', b'grows', b'thebes', b'called',
# Nearest to b'had': b'was', b'korzybski', b'artefacts', b'rotors', b'alaskans', b'hui', b'fields', b'is',
# Nearest to b'only': b'alkene', b'miriam', b'gland', b'paid', b'exercised', b'dispute', b'reginae', b'austin',
# Average loss at step  12000 :  14.3327022803
# Average loss at step  14000 :  11.617685606
# Average loss at step  16000 :  9.76677211607
# Average loss at step  18000 :  8.48275851536
# Average loss at step  20000 :  7.83779877484
# Nearest to b'some': b'subkey', b'the', b'many', b'victoriae', b'publisher', b'all', b'nhk', b'held',
# Nearest to b'but': b'and', b'alongside', b'victoriae', b'confessions', b'amo', b'dasyprocta', b'agouti', b'was',
# Nearest to b'not': b'to', b'also', b'elagabalus', b'it', b'differ', b'they', b'could', b'envelope',
# Nearest to b'this': b'the', b'it', b'which', b'a', b'one', b'inner', b'dasyprocta', b'there',
# Nearest to b'are': b'is', b'were', b'was', b'agouti', b'aloud', b'cauchy', b'four', b'imran',
# Nearest to b'has': b'is', b'was', b'had', b'absalom', b'kinds', b'agave', b'asserts', b'dasyprocta',
# Nearest to b'six': b'nine', b'eight', b'zero', b'seven', b'four', b'two', b'three', b'five',
# Nearest to b'i': b'diffuse', b'absalom', b'recruiting', b'faltered', b'bordered', b'he', UNK, b'aqua',
# Nearest to b'war': b'portrait', b'bed', b'stamp', b'spend', b'innocent', b'unfairly', b'austin', b'develop',
# Nearest to b'will': b'sappho', b'dried', b'to', b'surname', b'stylization', b'lettering', b'vary', b'raised',
# Nearest to b'would': b'can', b'to', b'anglicanism', b'tuned', b'athletics', b'off', b'ground', b'suffix',
# Nearest to b'if': b'msg', b'tao', b'agouti', b'quincy', b'dasyprocta', b'is', b'theism', b'resolution',
# Nearest to b'to': b'not', b'and', b'for', b'nine', b'in', b'would', b'neuter', b'zero',
# Nearest to b'see': b'heat', b'yardage', b'editor', b'absalom', b'two', b'imran', b'normed', b'thebes',
# Nearest to b'had': b'was', b'have', b'is', b'korzybski', b'has', b'were', b'splitter', b'hui',
# Nearest to b'only': b'hbox', b'alkene', b'dasyprocta', b'schwarzenegger', b'exercised', b'miriam', b'paid', b'birkenau',
# Average loss at step  22000 :  7.2469814676
# Average loss at step  24000 :  7.00789718211
# Average loss at step  26000 :  6.72072740936
# Average loss at step  28000 :  6.20069476712
# Average loss at step  30000 :  6.21716412497
# Nearest to b'some': b'many', b'all', b'the', b'their', b'victoriae', b'subkey', b'publisher', b'a',
# Nearest to b'but': b'and', b'abet', b'victoriae', b'confessions', b'dasyprocta', b'agouti', b'amo', b'alongside',
# Nearest to b'not': b'also', b'to', b'it', b'they', b'elagabalus', b'abakan', b'there', b'slots',
# Nearest to b'this': b'it', b'which', b'the', b'there', b'a', b'dasyprocta', b'akita', b'nonstandard',
# Nearest to b'are': b'were', b'is', b'aloud', b'have', b'was', b'agouti', b'comeback', b'amalthea',
# Nearest to b'has': b'is', b'was', b'had', b'have', b'absalom', b'already', b'kinds', b'when',
# Nearest to b'six': b'eight', b'four', b'nine', b'seven', b'five', b'three', b'zero', b'two',
# Nearest to b'i': b'diffuse', b'recruiting', b'bordered', b'he', b'absalom', b'breast', b'mdi', b'phi',
# Nearest to b'war': b'portrait', b'bed', b'innocent', b'stamp', b'spend', b'nr', b'vojt', b'unfairly',
# Nearest to b'will': b'to', b'sappho', b'can', b'surname', b'stylization', b'dried', b'analytic', b'vary',
# Nearest to b'would': b'can', b'to', b'tuned', b'may', b'anglicanism', b'could', b'athletics', b'off',
# Nearest to b'if': b'is', b'tao', b'msg', b'agouti', b'quincy', b'dasyprocta', b'resolution', b'andamanese',
# Nearest to b'to': b'would', b'for', b'nine', b'not', b'will', b'in', b'can', b'with',
# Nearest to b'see': b'yardage', b'heat', b'absalom', b'editor', b'quadrilateral', b'deo', b'barry', b'called',
# Nearest to b'had': b'was', b'have', b'has', b'were', b'is', b'korzybski', b'are', b'splitter',
# Nearest to b'only': b'hbox', b'dasyprocta', b'alkene', b'arrays', b'aba', b'exercised', b'then', b'schwarzenegger',
# Average loss at step  32000 :  5.82211605668
# Average loss at step  34000 :  5.84223541307
# Average loss at step  36000 :  5.68100128257
# Average loss at step  38000 :  5.25360511363
# Average loss at step  40000 :  5.46574739814
# Nearest to b'some': b'many', b'all', b'the', b'their', b'eskimo', b'several', b'other', b'victoriae',
# Nearest to b'but': b'and', b'lemmy', b'abet', b'dasyprocta', b'amo', b'agouti', b'victoriae', b'confessions',
# Nearest to b'not': b'to', b'also', b'it', b'they', b'elagabalus', b'abakan', b'there', b'slots',
# Nearest to b'this': b'it', b'which', b'the', b'there', b'that', b'dasyprocta', b'any', b'akita',
# Nearest to b'are': b'were', b'is', b'have', b'aloud', b'agouti', b'comeback', b'was', b'but',
# Nearest to b'has': b'had', b'is', b'was', b'have', b'absalom', b'already', b'been', b'kinds',
# Nearest to b'six': b'four', b'seven', b'eight', b'five', b'three', b'nine', b'zero', b'two',
# Nearest to b'i': b'he', b'diffuse', b'recruiting', UNK, b'bordered', b'breast', b'mail', b'absalom',
# Nearest to b'war': b'portrait', b'bed', b'rpg', b'vojt', b'nr', b'innocent', b'stamp', b'vma',
# Nearest to b'will': b'can', b'to', b'would', b'should', b'sappho', b'surname', b'neocortex', b'instant',
# Nearest to b'would': b'can', b'to', b'may', b'tuned', b'could', b'will', b'anglicanism', b'should',
# Nearest to b'if': b'is', b'agouti', b'msg', b'tao', b'quincy', b'dasyprocta', b'abet', b'andamanese',
# Nearest to b'to': b'not', b'for', b'would', b'nine', b'and', b'from', b'hbox', b'neuter',
# Nearest to b'see': b'yardage', b'absalom', b'heat', b'quadrilateral', b'editor', b'barry', b'are', b'called',
# Nearest to b'had': b'has', b'have', b'was', b'were', b'are', b'is', b'splitter', b'korzybski',
# Nearest to b'only': b'hbox', b'dasyprocta', b'alkene', b'arrays', b'exercised', b'flores', b'aba', b'then',
# Average loss at step  42000 :  5.30125885081
# Average loss at step  44000 :  5.46627238631
# Average loss at step  46000 :  5.30377979791
# Average loss at step  48000 :  5.02859449089
# Average loss at step  50000 :  5.18199024785
# Nearest to b'some': b'many', b'all', b'several', b'other', b'the', b'their', b'these', b'eskimo',
# Nearest to b'but': b'and', b'lemmy', b'dasyprocta', b'amo', b'victoriae', b'agouti', b'abet', b'however',
# Nearest to b'not': b'they', b'to', b'also', b'elagabalus', b'it', b'there', b'abakan', b'usually',
# Nearest to b'this': b'which', b'it', b'the', b'there', b'dasyprocta', b'that', b'thibetanus', b'akita',
# Nearest to b'are': b'were', b'is', b'have', b'aloud', b'agouti', b'was', b'comeback', b'be',
# Nearest to b'has': b'had', b'was', b'is', b'have', b'absalom', b'when', b'recitative', b'already',
# Nearest to b'six': b'eight', b'five', b'four', b'seven', b'three', b'nine', b'one', b'two',
# Nearest to b'i': b'he', b'recruiting', b'diffuse', UNK, b'mail', b'remini', b'bordered', b'absalom',
# Nearest to b'war': b'dipyramid', b'portrait', b'rpg', b'spend', b'bed', b'vojt', b'nr', b'unfairly',
# Nearest to b'will': b'can', b'would', b'to', b'should', b'could', b'may', b'instant', b'analytic',
# Nearest to b'would': b'can', b'may', b'could', b'to', b'will', b'tuned', b'should', b'might',
# Nearest to b'if': b'is', b'when', b'tao', b'quincy', b'agouti', b'msg', b'prism', b'but',
# Nearest to b'to': b'would', b'neuter', b'will', b'not', b'nine', b'can', b'hbox', b'from',
# Nearest to b'see': b'yardage', b'absalom', b'quadrilateral', b'barry', b'heat', b'solicitation', b'called', b'leasing',
# Nearest to b'had': b'has', b'have', b'was', b'were', b'is', b'korzybski', b'been', b'are',
# Nearest to b'only': b'hbox', b'exercised', b'arrays', b'alkene', b'dasyprocta', b'flores', b'geddes', b'until',
# Average loss at step  52000 :  5.15922809362
# Average loss at step  54000 :  5.11426029098
# Average loss at step  56000 :  5.07197252882
# Average loss at step  58000 :  5.10969238758
# Average loss at step  60000 :  4.93770928133
# Nearest to b'some': b'many', b'all', b'several', b'the', b'these', b'other', b'their', b'microsite',
# Nearest to b'but': b'and', b'callithrix', b'lemmy', b'however', b'amo', b'microcebus', b'dasyprocta', b'agouti',
# Nearest to b'not': b'to', b'they', b'it', b'elagabalus', b'also', b'interracial', b'usually', b'there',
# Nearest to b'this': b'it', b'which', b'the', b'there', b'that', b'a', b'one', b'dasyprocta',
# Nearest to b'are': b'were', b'is', b'have', b'aloud', b'microcebus', b'tamarin', b'agouti', b'pilsner',
# Nearest to b'has': b'had', b'was', b'have', b'is', b'absalom', b'callithrix', b'already', b'recitative',
# Nearest to b'six': b'five', b'eight', b'four', b'seven', b'three', b'nine', b'zero', b'two',
# Nearest to b'i': b'he', b'recruiting', b'diffuse', UNK, b'putatively', b'we', b'mail', b'remini',
# Nearest to b'war': b'dipyramid', b'portrait', b'nr', b'rpg', b'verses', b'innocent', b'bed', b'spend',
# Nearest to b'will': b'can', b'would', b'could', b'should', b'to', b'may', b'instant', b'analytic',
# Nearest to b'would': b'can', b'may', b'could', b'will', b'to', b'might', b'must', b'should',
# Nearest to b'if': b'when', b'is', b'tao', b'quincy', b'microcebus', b'agouti', b'msg', b'since',
# Nearest to b'to': b'not', b'neuter', b'would', b'callithrix', b'nine', b'will', b'hbox', b'can',
# Nearest to b'see': b'absalom', b'yardage', b'microcebus', b'callithrix', b'barry', b'quadrilateral', b'solicitation', b'heat',
# Nearest to b'had': b'has', b'have', b'was', b'were', b'korzybski', b'been', b'is', b'splitter',
# Nearest to b'only': b'hbox', b'arrays', b'until', b'exercised', b'ssbn', b'alkene', b'flores', b'dasyprocta',
# Average loss at step  62000 :  4.77924934816
# Average loss at step  64000 :  4.78903451288
# Average loss at step  66000 :  4.97831632566
# Average loss at step  68000 :  4.91899002373
# Average loss at step  70000 :  4.77754023302
# Nearest to b'some': b'many', b'several', b'all', b'these', b'other', b'the', b'their', b'microsite',
# Nearest to b'but': b'and', b'however', b'callithrix', b'thaler', b'lemmy', b'which', b'amo', b'microcebus',
# Nearest to b'not': b'to', b'they', b'elagabalus', b'often', b'it', b'also', b'abakan', b'interracial',
# Nearest to b'this': b'which', b'it', b'the', b'that', b'there', b'one', b'dasyprocta', b'thibetanus',
# Nearest to b'are': b'were', b'is', b'have', b'microcebus', b'was', b'be', b'aloud', b'agouti',
# Nearest to b'has': b'had', b'is', b'have', b'was', b'absalom', b'callithrix', b'amalthea', b'dasyprocta',
# Nearest to b'six': b'five', b'four', b'eight', b'seven', b'three', b'nine', b'zero', b'two',
# Nearest to b'i': b'he', b'recruiting', b'bokassa', b'we', b'diffuse', b'mail', b'seven', b'bordered',
# Nearest to b'war': b'dipyramid', b'portrait', b'verses', b'nr', b'rpg', b'bed', b'innocent', b'unfairly',
# Nearest to b'will': b'can', b'would', b'may', b'to', b'could', b'should', b'thaler', b'instant',
# Nearest to b'would': b'can', b'may', b'will', b'could', b'might', b'to', b'must', b'should',
# Nearest to b'if': b'when', b'microcebus', b'is', b'agouti', b'since', b'quincy', b'msg', b'tao',
# Nearest to b'to': b'will', b'would', b'not', b'neuter', b'callithrix', b'can', b'tamarin', b'hbox',
# Nearest to b'see': b'absalom', b'yardage', b'callithrix', b'barry', b'microcebus', b'quadrilateral', b'solicitation', b'leasing',
# Nearest to b'had': b'has', b'have', b'was', b'were', b'is', b'korzybski', b'been', b'are',
# Nearest to b'only': b'thaler', b'hbox', b'arrays', b'ssbn', b'until', b'dasyprocta', b'then', b'exercised',
# Average loss at step  72000 :  4.81550505471
# Average loss at step  74000 :  4.7845874896
# Average loss at step  76000 :  4.87084199893
# Average loss at step  78000 :  4.78795215642
# Average loss at step  80000 :  4.81466179502
# Nearest to b'some': b'many', b'several', b'all', b'these', b'other', b'their', b'the', b'various',
# Nearest to b'but': b'however', b'and', b'callithrix', b'thaler', b'when', b'lemmy', b'which', b'dasyprocta',
# Nearest to b'not': b'they', b'it', b'to', b'often', b'elagabalus', b'usually', b'abakan', b'be',
# Nearest to b'this': b'which', b'it', b'the', b'there', b'that', b'akita', b'nonstandard', b'thibetanus',
# Nearest to b'are': b'were', b'is', b'have', b'aloud', b'be', b'microcebus', b'these', b'spies',
# Nearest to b'has': b'had', b'have', b'was', b'is', b'absalom', b'callithrix', b'satanic', b'inn',
# Nearest to b'six': b'five', b'four', b'seven', b'eight', b'three', b'nine', b'two', b'zero',
# Nearest to b'i': UNK, b'pontificia', b'we', b'he', b'ii', b'diffuse', b'bokassa', b'putatively',
# Nearest to b'war': b'dipyramid', b'portrait', b'rpg', b'verses', b'innocent', b'nr', b'unfairly', b'spend',
# Nearest to b'will': b'can', b'would', b'may', b'should', b'could', b'to', b'thaler', b'might',
# Nearest to b'would': b'can', b'may', b'will', b'could', b'might', b'must', b'should', b'to',
# Nearest to b'if': b'when', b'since', b'microcebus', b'agouti', b'quincy', b'msg', b'is', b'callithrix',
# Nearest to b'to': b'callithrix', b'would', b'neuter', b'will', b'not', b'nine', b'for', b'hbox',
# Nearest to b'see': b'absalom', b'callithrix', b'yardage', b'barry', b'microcebus', b'quadrilateral', b'leasing', b'solicitation',
# Nearest to b'had': b'has', b'have', b'was', b'were', b'korzybski', b'been', b'when', b'turboprop',
# Nearest to b'only': b'thaler', b'hbox', b'until', b'arrays', b'then', b'ssbn', b'dasyprocta', b'exercised',
# Average loss at step  82000 :  4.80299883044
# Average loss at step  84000 :  4.79732315516
# Average loss at step  86000 :  4.7543967551
# Average loss at step  88000 :  4.69366198432
# Average loss at step  90000 :  4.75382099569
# Nearest to b'some': b'many', b'several', b'these', b'all', b'other', b'the', b'various', b'their',
# Nearest to b'but': b'however', b'and', b'callithrix', b'which', b'thaler', b'although', b'when', b'lemmy',
# Nearest to b'not': b'they', b'often', b'elagabalus', b'to', b'it', b'abakan', b'usually', b'bokassa',
# Nearest to b'this': b'it', b'which', b'the', b'there', b'that', b'akita', b'thibetanus', b'some',
# Nearest to b'are': b'were', b'is', b'have', b'aloud', b'these', b'be', b'include', b'comeback',
# Nearest to b'has': b'had', b'have', b'is', b'was', b'absalom', b'callithrix', b'inn', b'satanic',
# Nearest to b'six': b'eight', b'seven', b'five', b'four', b'three', b'nine', b'zero', b'two',
# Nearest to b'i': b'pontificia', b'ii', b'we', b'bokassa', b'repulsive', b'diffuse', b'mail', b'dcsd',
# Nearest to b'war': b'dipyramid', b'rpg', b'verses', b'portrait', b'innocent', b'unfairly', b'cuauht', b'spend',
# Nearest to b'will': b'can', b'would', b'may', b'could', b'should', b'to', b'might', b'must',
# Nearest to b'would': b'can', b'may', b'will', b'could', b'might', b'must', b'should', b'to',
# Nearest to b'if': b'when', b'since', b'is', b'microcebus', b'agouti', b'msg', b'tamarin', b'but',
# Nearest to b'to': b'would', b'will', b'callithrix', b'neuter', b'not', b'can', b'bakersfield', b'nine',
# Nearest to b'see': b'absalom', b'callithrix', b'quadrilateral', b'yardage', b'barry', b'microcebus', b'solicitation', b'leasing',
# Nearest to b'had': b'has', b'have', b'was', b'were', b'having', b'korzybski', b'been', b'is',
# Nearest to b'only': b'thaler', b'hbox', b'arrays', b'until', b'ssbn', b'then', b'dasyprocta', b'exercised',
# Average loss at step  92000 :  4.70487690389
# Average loss at step  94000 :  4.63770308995
# Average loss at step  96000 :  4.73774142432
# Average loss at step  98000 :  4.60714254904
# Average loss at step  100000 :  4.67983694923
# Nearest to b'some': b'many', b'several', b'these', b'all', b'other', b'the', b'their', b'various',
# Nearest to b'but': b'and', b'however', b'although', b'callithrix', b'when', b'thaler', b'which', b'though',
# Nearest to b'not': b'they', b'often', b'interracial', b'elagabalus', b'usually', b'to', b'it', b'abakan',
# Nearest to b'this': b'which', b'it', b'the', b'there', b'one', b'that', b'akita', b'thibetanus',
# Nearest to b'are': b'were', b'is', b'have', b'be', b'include', b'aloud', b'these', b'comeback',
# Nearest to b'has': b'had', b'have', b'was', b'is', b'absalom', b'callithrix', b'amalthea', b'almighty',
# Nearest to b'six': b'seven', b'five', b'four', b'eight', b'nine', b'three', b'two', b'zero',
# Nearest to b'i': b'we', b'ii', b'pontificia', b'you', b'mail', b'repulsive', b'bokassa', b'diffuse',
# Nearest to b'war': b'dipyramid', b'rpg', b'verses', b'innocent', b'portrait', b'unfairly', b'cuauht', b'embellishment',
# Nearest to b'will': b'can', b'would', b'may', b'could', b'should', b'to', b'must', b'might',
# Nearest to b'would': b'can', b'may', b'will', b'could', b'might', b'must', b'should', b'to',
# Nearest to b'if': b'when', b'since', b'where', b'microcebus', b'is', b'agouti', b'msg', b'tamarin',
# Nearest to b'to': b'will', b'would', b'callithrix', b'can', b'nine', b'eight', b'tamarin', b'hbox',
# Nearest to b'see': b'absalom', b'barry', b'callithrix', b'yardage', b'quadrilateral', b'microcebus', b'leasing', b'solicitation',
# Nearest to b'had': b'has', b'have', b'was', b'were', b'having', b'is', b'turboprop', b'korzybski',
# Nearest to b'only': b'thaler', b'hbox', b'then', b'until', b'ssbn', b'dasyprocta', b'arrays', b'aba',
