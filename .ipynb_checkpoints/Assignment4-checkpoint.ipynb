# %% [markdown]
# # Assignment4
# ## 컴퓨터공학부 2016136121 정태훈

# %% [markdown]
# ----------------------------

# %%
stopword = []
with open('stopword.txt', 'r') as f:
    for line in f:
        if(line != "\n") :
            stopword.append(line.strip())
                
print(stopword)
# Out:
# ['a', 'about', 'above', 'across', 'after', 'again', 'against', 'all', 'almost', 'alone', 'along', 'already', 'also', 'although', 'always', 'among', 'an', 'and', 'another', 'any', 'anybody', 'anyone', 'anything', 'anywhere', 'are', 'area', 'areas', 'around', 'as', 'ask', 'asked', 'asking', 'asks', 'at', 'away', 'b', 'back', 'backed', 'backing', 'backs', 'be', 'became', 'because', 'become', 'becomes', 'been', 'before', 'began', 'behind', 'being', 'beings', 'best', 'better', 'between', 'big', 'both', 'but', 'by', 'c', 'came', 'can', 'cannot', 'case', 'cases', 'certain', 'certainly', 'clear', 'clearly', 'come', 'could', 'd', 'did', 'differ', 'different', 'differently', 'do', 'does', 'done', 'down', 'down', 'downed', 'downing', 'downs', 'during', 'e', 'each', 'early', 'either', 'end', 'ended', 'ending', 'ends', 'enough', 'even', 'evenly', 'ever', 'every', 'everybody', 'everyone', 'everything', 'everywhere', 'f', 'face', 'faces', 'fact', 'facts', 'far', 'felt', 'few', 'find', 'finds', 'fir
# ...

# %% [markdown]
# ## 문제 1
# L=[1, 2, 3, 4, 5]일 때 다음 각 문장을 수행한 후의 결과를 보고 납득할 만한 이유를 설명하시오.
#
# 1)
# ``` python
#     L[1:3] = [100]
#     print(L)
# ```
# 2)
# ``` python
#     L[1:3] = [(100)]
#     print(L)
#     ```
# 3)
# ``` python
#     L[1:3] = 100
#     print(L)
#     ```
# 4)
# ``` python
#     L[1:3] = (100)
#     print(L)
#     ```
# 5)
# ``` python
#     L[1:3] = (100, 101, 102)
#     print(L)
#     ```
# 6)
# ``` python
#     L[1:3] = [100, 101, 102]
#     print(L)
#     ```
# 7)
# ``` python
#     L[1:3] = [(100, 101, 102)]
#     print(L)
#     ```
# 8)
# ``` python
#     L[1:3] = [[100, 101, 102]]
#     print(L)
#     ```

# %% [markdown]
# #### 1-1 문제

# %%
L=[1, 2, 3, 4, 5]
L[1:3] = [100]
print(L)
# Out:
# [1, 100, 4, 5]

# %% [markdown]
# #### 1-1 해설

# %%
L=[1, 2, 3, 4, 5]
print(L[1:3] == [2,3])
L[1:3] = [100]
print(L == [1, 100, 4,5])
# Out:
# True
# True

# %% [markdown]
# L[1:3]의 경우 L[1]부터 L[2]까지를 나타내며 그렇기에
# ``` python
# L[1:3] == [2,3]
# ```
# 의 결과가 true로 나옵니다.
#
# 그리고 이 값을 [100]으로 바꾸기에 기존에 [2,3]의 부분은 [100]으로 바뀌게 되고,
# L은 리스트 객체이기에 값 변경이 가능해
# ``` python
# L = [1, 100, 4, 5]
# ```
# 이 됩니다.

# %% [markdown]
# #### 1-2 문제

# %%
L=[1, 2, 3, 4, 5]
L[1:3] = [(100)]
print(L)
# Out:
# [1, 100, 4, 5]

# %% [markdown]
# #### 1-2 해설

# %%
L=[1, 2, 3, 4, 5]
print(L[1:3] == [2,3])
L[1:3] = [(100)]
t = (100)
print(type(t))
t = ('a')
print(type(t))
print(L == [1, (100), 4,5])
print(L == [1, 100, 4,5])
# Out:
# True
# <class 'int'>
# <class 'str'>
# True
# True

# %% [markdown]
# L[1:3]의 경우 L[1]부터 L[2]까지를 나타내며 그렇기에
# ``` python
# L[1:3] == [2,3]
# ```
# 의 결과가 true로 나옵니다.
#
# 그리고 이 값을 [(100)]으로 바꾸기에 기존에 [2,3]의 부분은 [(100)]으로 바뀌게 되는데,
# 튜플에서 값이 1개만 들어가게 되면 튜플이 아닌 내부에 해당하는 값의 타입으로 인식하기 때문에 일반 int와 동일하게 저장됩니다.
# 그러므로
# ``` python
# L = [1, 100, 4, 5]
# ```
# 이 됩니다.

# %% [markdown]
# #### 1-3 문제

# %%
L=[1, 2, 3, 4, 5]
L[1:3] = 100
print(L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-d0274ea64f39> in <module>()
#       1 L=[1, 2, 3, 4, 5]
# ----> 2 L[1:3] = 100
#       3 print(L)
#
# TypeError: can only assign an iterable

# %% [markdown]
# #### 1-3 해설

# %%
L=[1, 2, 3, 4, 5]
print(type(L[1:3]))
print(type(100))
L[1:3] = 100
# Out:
# <class 'list'>
# <class 'int'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-1e93b706cbb5> in <module>()
#       2 print(type(L[1:3]))
#       3 print(type(100))
# ----> 4 L[1:3] = 100
#
# TypeError: can only assign an iterable

# %%
L=[1, 2, 3, 4, 5]
print(type(L[1:3]))
print(type([100]))
L[1:3] = [100]
print(L)
# Out:
# <class 'list'>
# <class 'list'>
# [1, 100, 4, 5]

# %% [markdown]
# L[1:3]의 type는 list입니다.. 그런데 문제에서 L[1:3]에 100을 대입하려고 하는데, 이 둘은 위와 같이 서로 type이 다릅니다. 100의 값의 type는 int이기에 L[1:3]의 type인 list와 다릅니다. 그렇기에 대입하는 과정에서 오류가 생깁니다.
#
# 오류의 내용은 "can only assign an iterable"인데, 이는 L[1:3]에 접근 가능한 건 iterable만 가능하다는 뜻이며, iterable은 시퀸스 자료형인 list, str, tuple에 해당합니다. 그래서 이를 해결하려면 [100]으로 바꿔 list로 변경해주면 됩니다. 그렇게 하면 오류가 걸리지 않고 값이 정상적으로 들어가지게 됩니다.

# %% [markdown]
# #### 1-4 문제

# %%
L=[1, 2, 3, 4, 5]
L[1:3] = (100)
print(L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-f155c5a8ccd1> in <module>()
#       1 L=[1, 2, 3, 4, 5]
# ----> 2 L[1:3] = (100)
#       3 print(L)
#
# TypeError: can only assign an iterable

# %% [markdown]
# #### 1-4 해설

# %%
L=[1, 2, 3, 4, 5]
print(type(L[1:3]))
print(type((100)))
L[1:3] = (100)
# Out:
# <class 'list'>
# <class 'int'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-eb28725d1704> in <module>()
#       2 print(type(L[1:3]))
#       3 print(type((100)))
# ----> 4 L[1:3] = (100)
#
# TypeError: can only assign an iterable

# %%
L[1:3] = (100,)
print(L)
# Out:
# [1, 100, 4, 5]

# %% [markdown]
# L[1:3]의 경우 L[1]부터 L[2]까지를 나타내며 그렇기에
# ``` python
# L[1:3] == [2,3]
# ```
# 의 결과가 true로 나옵니다.
# 그리고 L[1:3]의 type는 list입니다.
#
# 그런데 문제에서 L[1:3]에 (100)을 대입하려고 하는데, 이 둘은 위와 같이 서로 type이 다릅니다. (100)의 경우는 얼핏 보면 tuple이지만, 튜플에 값이 1개밖에 없으면 내부 값의 type를 그대로 따라가게 되기에 int를 type로 하게 됩니다. 그렇기에 대입하는 과정에서 오류가 생깁니다.
#
# 오류의 내용은 "can only assign an iterable"인데, 이는 L[1:3]에 접근 가능한 건 iterable만 가능하다는 뜻이며, iterable은 시퀸스 자료형인 list, str, tuple에 해당합니다. 그래서 이를 튜플로 바꿔주려면 (100,)로 해주면 됩니다. 그렇게 하면 오류가 걸리지 않고 값이 정상적으로 들어가지게 됩니다.

# %% [markdown]
# #### 1-5 문제

# %%
L=[1, 2, 3, 4, 5]
L[1:3] = (100, 101, 102)
print(L)
# Out:
# [1, 100, 101, 102, 4, 5]

# %% [markdown]
# #### 1-5 해설

# %% [markdown]
# 1-3에서 얘기했던 것과 같이 iterable에 접근 가능한 객체는 iterable이며 대표적인 iterable로는 시퀸스 자료형인 list, str, tuple입니다. 그리고 list의 경우는 값 변경이 가능하기에 튜플을 대입하면 안의 데이터들이 그대로 옮겨지게 됩니다. 문제에서는 L[1] ~ L[2]까지의 범위 안에 100, 101, 102값을 넣는 것이기에 [1, 100, 102, 102, 4, 5]가 출력됩니다.

# %% [markdown]
# #### 1-6 문제

# %%
L=[1, 2, 3, 4, 5]
L[1:3] = [100, 101, 102]
print(L)
# Out:
# [1, 100, 101, 102, 4, 5]

# %% [markdown]
# #### 1-6 해설

# %% [markdown]
# tuple에서 list로 변경된 것 빼면 1-4 문제와 똑같은 문제라고 보면 됩니다. tuple, list 모두 iterable에 해당하고 대입하려고 하는 객체는 list이고 현재 L은 리스트이기에 값이 변경 가능합니다. 그래서 1-4와 동일한 결과가 나타납니다.

# %% [markdown]
# #### 1-7 문제

# %%
L=[1, 2, 3, 4, 5]
L[1:3] = [(100, 101, 102)]
print(L)
# Out:
# [1, (100, 101, 102), 4, 5]

# %% [markdown]
# #### 1-7 해설

# %% [markdown]
# L[1:3]은 List이고, 내부의 값은 2, 3인 두 개의 int객체입니다. 그리고 이 L[1:3]의 값들을 [(100,101,102)]로 변경하려고 합니다. [(100,101,102)] 리스트의 내부 값은 (100, 101, 102)인 한 개의 tuple객체입니다. 다시 말해 두개의 int객체를 한 개의 tuple객체로 변경하겠다는 뜻입니다. 그렇기에 안에 tuple객체가 들어가면서 [1, (100, 101, 102), 4, 5]로 바뀌게 됩니다.

# %% [markdown]
# #### 1-8 문제

# %%
L=[1, 2, 3, 4, 5]
L[1:3] = [[100, 101, 102]]
print(L)
# Out:
# [1, [100, 101, 102], 4, 5]

# %% [markdown]
# #### 1-8 해설

# %% [markdown]
# L[1:3]은 List이고, 내부의 값은 2, 3인 두 개의 int객체입니다. 그리고 이 L[1:3]의 값들을 [[100,101,102]]로 변경하려고 합니다. [[100,101,102]] 리스트의 내부 값은 [100, 101, 102]인 한 개의 list객체입니다. 다시 말해 두개의 int객체를 한 개의 list객체로 변경하겠다는 뜻입니다. 그렇기에 안에 list객체가 들어가면서 [1, [100, 101, 102], 4, 5]로 바뀌게 됩니다.

# %% [markdown]
# -----------------------------

# %% [markdown]
# ## 문제 2

# %% [markdown]
# 문자열 S = 'Hello World and Python'에 대해 다음 요구사항에 대한 Python 코드를 제시하시오.
#
#     1) 단어의 순서가 역순으로 되어진 문자열 ('Python and World Hello')을 만들고
#
#     2) 1)의 결과 문자열에 대해 메소드 split과 join을 이용하여 공백을 모두 없엔 문자열 'PythonandWorldHello'을 만드시오.

# %%
S = 'Hello World and Python'
r = S.split(' ')
r.reverse()
r = " ".join(r)
print(r)
# Out:
# Python and World Hello

# %%
t = r.split(" ")
t = "".join(t)
print(t)
# Out:
# PythonandWorldHello

# %% [markdown]
# #### 해설 : 문제 2

# %% [markdown]
# 문자열이 입력되면 먼저 이 문자열을 띄어쓰기(' ')를 기준으로 분리해서 단어의 뭉치로 만들어줍니다.

# %%
S = 'Hello World and Python'
r = S.split(' ')
print(r)
# Out:
# ['Hello', 'World', 'and', 'Python']

# %% [markdown]
# 그 다음 이 순서를 역으로 하기 위해 reverse 함수를 이용합니다.

# %%
r.reverse()
print(r)
# Out:
# ['Python', 'and', 'World', 'Hello']

# %% [markdown]
# 역순으로 배열이 되었다면 이제 list를 하나의 string으로 만들어주는데, 이때는 join을 사용합니다. join 앞에 들어가는 건 list안의 객체가 하나로 합쳐실 때 그 사이에 어떤 것을 넣게 할 지 정해주는 것입니다. 여기서는 띄어쓰기(' ')를 넣어서 순서가 역순으로 된 문자열이지만 단어 하나하나는 그대로인 상태로 만듭니다.

# %%
r = " ".join(r)
print(r)
# Out:
# Python and World Hello

# %% [markdown]
# 그 다음 리스트에서 맨 마지막 요소만 따로 가져오고, 맨 마지막 요소를 제외한 리스트는 다시 원래대로 돌려야하는데, 이 때는 join을 이용한다. 이렇게 하면 리스트가 문자열로 다시 뭉쳐지며, 뭉쳐지는 과정에서 리스트 요소 사이에는 "/"이 삽입됩니다. 그리고 새로운 list 변수 l을 만든 다음에 append를 사용하여 디렉토리, 파일명 하나씩 넣습니다. 그리고 list를 출력하면 원하는 결과가 출력됩니다.

# %%
t = r.split(" ")
t = "".join(t)
print(t)
# Out:
# PythonandWorldHello

# %% [markdown]
# 이제 공백을 없애는 방법으로는 다시 공백을 기준으로 split해서 list로 만들어 준 다음, 다시 뭉칠 때는 사이에 공백이 없게 합쳐주어서 string으로 바꿔 주면 문제에서 원하는 결과대로 String 객체가 만들어지게 됩니다.

# %% [markdown]
# -----------------------

# %% [markdown]
# ## 문제 3
# 다음 코드를 보고 물음에 답하시오.
# ``` python
# a = [1, 2, 3]
# b = a * 3
# c = [a] * 3
# print(b)
# print(c)
# ```
# 1) 위 코드를 수행한 이후 다음 코드를 수행한 후 b와 c의 내용을 확인하시오.
# ```
# a[0]=0
# ```
# 2) b와 c 객체의 차이는 무엇인가?

# %%
a = [1, 2, 3]
b = a * 3
c = [a] * 3
print(b)
print(c)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]

# %%
a[0]=0
print(b)
print(c)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[0, 2, 3], [0, 2, 3], [0, 2, 3]]

# %% [markdown]
# #### 해설 : 문제3

# %% [markdown]
# b와 c의 차이는 어떤 객체를 넣었느냐의 차이가 있습니다. b에 들어간 객체는 a 안의 값인 int이고, c에 들어간 객체는 a를 list로 묵은 list객체입니다. 그리고 변경한 값은 a 리스트 값의 첫번째 값입니다. 그렇기에 값이 바뀐 건 list객체입니다. b에 들어간 값은 int 객체이기에 한번 값이 들어가면 더이상 a의 변화에도 값의 변화가 없습니다. 그러나 c에 들어간 값은 list 객체이기에 a의 값이 변하면 그에 맞게 값이 변하게 됩니다.
#
# 그렇기에 결과적으로 b는 a 안의 값이 변화해도 값이 그대로 유지되고, c는 a 값이 변화되면 그에 맟줘 값이 변하게 됩니다.

# %% [markdown]
# ## 문제 4

# %% [markdown]
# 다음 문자열을 ':'을 기준으로 분리하여 리스트로 만들고 각 문자열의 좌우 공백을 제거하시오 (즉, 문자열 S에서 l을 만들어라)
# ```
# s = '  first star   :   second star   :    third star  '
# l = ['first star', 'second star', 'third star']
# ```
# 1) for ~ in 문을 이용한 코드를 작성하시오.
#
# 2) 리스트 내포(list comprehension)를 이용한 코드를 작성하시오.

# %%
s = '  first star   :   second star   :    third star  '

m = s.split(':')
l = []
for i in m:
    l.append(i.strip())
print(l)
# Out:
# ['first star', 'second star', 'third star']

# %%
l = [ i.strip() for i in s.split(':') ]
print(l)
# Out:
# ['first star', 'second star', 'third star']

# %% [markdown]
# #### 문제 4 해설

# %%
s = '  first star   :   second star   :    third star  '

m = s.split(':')
print(m)
# Out:
# ['  first star   ', '   second star   ', '    third star  ']

# %% [markdown]
# 먼저 해당 문자열은 :로 나누면 위와 같이 나눠지는데 문제에서는 양 옆의 공백을 제거하는 것이 목표이므로 strip()을 사용해서 공백들을 제거해줍니다. 여기서 for ~ in을 사용하는 방법은 index를 이용해서 기존에 list의 값에 strip()을 사용해서 변경된 값을 다시 넣는 방법도 있지만, 빈 list 변수를 새로 만들어준 다음에 변경된 값을 새 list에 넣어주는 것이 코딩했을 때 더 편하게 구현할 수 있습니다.
#
# 하지만 그것보다 더 간단한 방법은 리스트 내포를 이용하는 방법입니다. s.split(':')을 for ~ in 안에 넣어주고, 값은 i.strip()으로 해주면 됩니다. 그렇게 하면 더 간단하게 구현할 수 있습니다.

# %% [markdown]
# ## 문제 5

# %% [markdown]
# 다음과 같이 0보다 큰 정수 리스트 변수 list를 인자로 받는 함수 addall(list)와 addallodd(list)를 for ~ in 리터널과 리스트 내포 방식으로 각각 제시하시오.
#
# 1) addall(list) 함수 (리스트 내의 모든 정수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)
# ```
# >>> addall([1])
# 1
# >>> addall([1, 2, 3, 4, 5, 6, 7, 8, 9])
# 45
# ```
#
# 2) addallodd(list) 함수 (리스트내의 모든 홀수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)
# ```
# >>> addallodd([1])
# 1
# >>> addallodd([1, 2, 3, 4, 5, 6, 7, 8, 9])
# 25
# ```
#
# - [참고 1]: 리스트 내포 방식으로 addall() 및 addallodd()함수를 만들 때엔 리스트 내포에 의해 생성된 리스트 결과에 대해 내장 함수를 사용하는 방식을 고려해보시오 (주의: 리스트 내포 방식의 addall() 및 addallodd() 함수의 몸체는 단 1줄로 작성되어야 한다.)
# - [참고 2]: sum() 등의 내장함수 사용 가능함

# %%
def addall(lst):
    sum = 0
    for i in lst:
        sum += i
    return sum

print(addall([1, 2, 3, 4, 5, 6, 7, 8, 9]))
# Out:
# 45

# %%
def addall(lst):
    return sum([i for i in lst])

print(addall([1, 2, 3, 4, 5, 6, 7, 8, 9]))
# Out:
# 45

# %%
def addallodd(lst):
    sum = 0
    for i in lst:
        if i % 2 == 1:
            sum += i
    return sum

print(addallodd([1, 2, 3, 4, 5, 6, 7, 8, 9]))
# Out:
# 25

# %%
def addallodd(lst):
    return sum([i for i in lst if i % 2 == 1])

print(addallodd([1, 2, 3, 4, 5, 6, 7, 8, 9]))
# Out:
# 25

# %% [markdown]
# #### 문제5 해설

# %% [markdown]
# 먼저 for ~ in 방식을 사용할 때에는 sum이란 리터럴을 생성해서 0으로 초기화시킵니다. 그 다음 for ~ in을 통해 값을 하나씩 가져와서 각 값들을 sum에 더해줍니다. 여기서 만약 addalodd 함수의 경우는 홀수만 더해주기로 했기에 for ~ in 안에 if i % 2 == 1로 필터링해서 나온 결과만 sum에 더해줍니다. 그리고 모두 더했다면 sum을 return시킵니다.
#
# 다만 이 문제는 리스트 내포 방식으로도 가능합니다. 여기서는 sum()내장함수를 이용하는데, list를 넣어주면 list 내부의 값을 모두 더한 값을 반환해줍니다. 먼저 리스트 내포 방식으로 리스트를 만들면 다음과 같습니다.
# ```python
# [i for i in lst]
# ```
# 여기에 홀수만 필터링하고자하면 for ~ in 다음에 if i % 2 == 1을 하나 추가합니다.
# ```python
# [i for i in lst if i % 2 == 1]
# ```
# 이렇게 해당하는 list를 만들었다면 이를 sum()내장 함수에 넣어서 이를 return시키면 for ~ in을 사용한 방식보다 더 짧게 구현할 수 있습니다.

# %% [markdown]
# ## 문제 6

# %% [markdown]
# 다음 코드를 보고 물음에 답하시오.
# ```
# L1 = [1, 2, 3]
# L2 = [4, 5, 6]
# d = {'low':L1, 'high':L2}
# e = d
# f = d.copy()
# print(d)
# print(e)
# print(f)
# print()
# d['low'] = [10, 20, 30]
# d['high'][1] = 500
# print(d)
# print(e)
# print(f)
# ```
# 1) 위 코드의 수행 결과 d와 e는 항상 같은 결과를 출력한다. 그 이유는 무엇인가?
#
# 2) 위 코드의 수행 결과 마지막 f의 내용은 다음과 같다. 이 때 'high' 키의 값 내용 중 500이 출력된 이유와 'low' 키의 값 내용 중 [1, 2, 3]이 출력된 이유를 설명하시오 ([hint]: shallow copy 관점에서 설명하시오.)
# ```
# {'high': [4, 500, 6], 'low': [1, 2, 3]}
# ```

# %%
L1 = [1, 2, 3]
L2 = [4, 5, 6]
d = {'low':L1, 'high':L2}
e = d
f = d.copy()
print(d)
print(e)
print(f)
print()
d['low'] = [10, 20, 30]
d['high'][1] = 500
print(d)
print(e)
print(f)
# Out:
# {'low': [1, 2, 3], 'high': [4, 5, 6]}
# {'low': [1, 2, 3], 'high': [4, 5, 6]}
# {'low': [1, 2, 3], 'high': [4, 5, 6]}
#
# {'low': [10, 20, 30], 'high': [4, 500, 6]}
# {'low': [10, 20, 30], 'high': [4, 500, 6]}
# {'low': [1, 2, 3], 'high': [4, 500, 6]}

# %% [markdown]
# #### 6-1 해설

# %%
print(id(d))
print(id(e))
print(id(f))
# Out:
# 2080241688648
# 2080241688648
# 2080241688720

# %% [markdown]
# e = d를 하게 되면 d의 값을 그대로 가져오지만 d의 메모리를 공유하고 있기 때문에 d를 그대로 가리키는 포인터같은 형태가 됩니다. 그래서 e는 d값이 변하면 그 값 그대로 따라가게 됩니다. 그리고 f처럼 copy함수를 이용해서 복사를 하면 값을 그대로 가져오는 건 e와 동일하지만, d의 메모리를 공유하지 않고 별개의 메모리를 새로 생성하고, 내부 값들의 메모리는 공유하는 형태가 됩니다. 이를 Shallow Copy(얕은 복사)라고 합니다.

# %% [markdown]
# #### 6-2 해설

# %%
print(id(d['low']))
print(id(f['low']))
print()
print(id(d['high']))
print(id(f['high']))
# Out:
# 2080241655304
# 2080241654984
#
# 2080241654920
# 2080241654920

# %% [markdown]
# d의 low키에 대한 내부 값은 list 객체를 새로 바뀌게 되면서([10, 20, 30]) 메모리 값이 변하게 됩니다. 하지만, f의 경우 기존의 list 객체([1, 2, 3])를 계속 갖고 있기 때문에 값이 변하지 않습니다. 하지만 d의 high키에 대한 내부 값의 경우 list 객체 자체는 바뀌지 않기 때문에 list 객체의 메모리값은 유지된 상태에서 list 내부 값이 변경되었습니다. 여기서 f의 경우 list 객체를 d와 계속 공유하고 있기 때문에 값이 바뀌게 됩니다.

# %% [markdown]
# ## 문제 7

# %% [markdown]
# 사전 d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}가 주어졌을 때 다음 요구사항에 맞는 코드를 제시하시오
# - [참고]: d.keys(), d.values()를 통해 리스트를 얻어낸 후 리스트가 지니고 있는 sort(cmp=None, key=None, reverse=False)함수를 활용하시오.
#
# 1) 키의 알파벳 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
#
# 2) 키의 알파벳 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
#
# 3) 값의 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
#
# 4) 값의 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.

# %%
def sort_val(d):
    return d[1]
d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}
keys = list(d.keys())
items = list(d.items())

# %%
keys.sort()
for i in keys:
    print(i, d[i])
# Out:
# five 5
# four 4
# one 1
# three 3
# two 2

# %%
keys.sort(reverse=True)
for i in keys:
    print(i, d[i])
# Out:
# two 2
# three 3
# one 1
# four 4
# five 5

# %%
items.sort(key=lambda d: d[1])
for k,v in items:
    print(k,v)
# Out:
# one 1
# two 2
# three 3
# four 4
# five 5

# %%
items.sort(key=lambda d: d[1], reverse=True)
for k,v in items:
    print(k,v)
# Out:
# five 5
# four 4
# three 3
# two 2
# one 1

# %% [markdown]
# +) 함수로 구현

# %%
items.sort(key=sort_val)
for k,v in items:
    print(k,v)
# Out:
# one 1
# two 2
# three 3
# four 4
# five 5

# %% [markdown]
# #### 문제7 해설

# %% [markdown]
# 튜플을 키로 sort하는 것은 값을 sort하는 것보다는 간단합니다. 먼저 d.keys()를 통해 key값을 받아서 list에 보관한 다음에, 이를 sort한 다음, for ~ in을 이용해서 sort한 키에 대해서 값을 출력시키면 키가 sort된 상태에서 출력이 됩니다. 여기서 역으로 sort를 하려면 sort함수에 reverse=True로 주면 됩니다.

# %% [markdown]
# 이제 값을 sort하는데, 대부분 값을 sort하려면 sorted란 외부 함수를 사용하는 방법도 있지만, sort를 사용하면서 이를 구현하려면 함수를 이용합니다. 이번엔 한번 lambda를 이용해보았습니다. 여기서 lambda는 C언어에서 inline함수와 비슷하다고 할 수 있습니다. 예시는 다음과 같습니다.

# %%
def add_func(x, y):
    return x+y
print(add_func(2,3))
print((lambda x, y : x+y)(2,3))
# Out:
# 5
# 5

# %% [markdown]
# lambda를 이용하면 간단한 함수를 더 간단하게 구현할 수 있습니다. 그리고 이 lambda를 key값에 넣게 되면 데이터 뭉치에서 원하는 값만 가져와서 그 값에 따른 sort가 가능합니다. 먼저 d.items()을 통해 키와 값이 모두 모여있는 list로 만든 다음, 함수를 이용하여 여기에서 값을 기준으로 이를 sort해줍니다. 역으로 하려면 아까처럼 reverse=True시키면 됩니다. 그리고 이를 for ~ in을 이용해서 출력하면 키에 따라 정렬된 상태로 출력하게 됩니다. 참고로 이 방법은 key로 정렬하는 것도 가능합니다.

# %% [markdown]
# ------------------------------

# %% [markdown]
# ## ACM-ICPC 문제 1152번

# %% [markdown]
# 영어 대소문자와 띄어쓰기만으로 이루어진 문장이 주어진다. 이 문장에는 몇 개의 단어가 있을까? 이를 구하는 프로그램을 작성하시오. 단, 단어는 띄어쓰기 하나로 구분된다고 생각한다.

# %%
print(len(input().split()))
# Out:
# The Curious Case of Benjamin Button
# 6

# %% [markdown]
# ![1152](img/1152.PNG)

# %% [markdown]
# #### 해설: ACM-ICPC 문제 1152번

# %% [markdown]
# input()을 통해 문장을 받으면, 이를 띄어쓰기를 기준으로 나눠주는데 이는 split()을 사용하면 됩니다. 이 때 주의해야 할 것은 임의로 split(' ')을 사용하면 중간에 틀렸다는 결과가 나오는데, 사실 이 부분은 아직도 왜 이러는지는 잘 모르겠습니다. 이제 split()을 사용해 단어 단위로 분해했다면 단어 갯수가 몇 개가 나왔는지 확인해봅니다. 이는 len()을 통해 알 수 있습니다. 이렇게 단어 갯수가 나오면 그 값을 출력하면 문제가 원하는 결과를 출력해주게 됩니다.

# %% [markdown]
# + plus) python과 같은 스크립트 언어인 Ruby로 이 문제를 풀었을 때의 코드는 다음과 같았습니다.
# ``` Ruby
# puts(gets.split.length)
# ```

# %% [markdown]
# -------------------------------------

# %% [markdown]
# ## Incremental Project

# %% [markdown]
# [Incremental Project] 이전 Assignment 2의 마지막 문제는 웹 URL로 지정된 웹페이지를 문자열로 가져와 모든 HTML 태그 및 CSS와 Javascript를 제외한 순수 텍스트를 얻어내고 그 안에 존재하는 단어를 추출하고 단어들의 총 개수를 출력하는 프로그램을 작성하는 것이었다. 이번에는 그 마지막 숙제를 그대로 확장하여 웹 URL로 지정된 웹페이지 내 순수 텍스트 안에 존재하는 각 단어들에 대해 다음 요구사항 대로 출력하는 프로그램을 작성하시오.
# - 요구사항 1. 순수 텍스트 안에 존재하는 단어들에 대해 string 모듈을 활용하여 모든 punctuation (구두문자)를 완벽히 제거하시오.
#     - 예: ['world!', ':', '+hello+', '~python$$$', '=', 'world'] ---> ['world', 'hello', 'python', 'world']
#     - 모든 punctuation을 확인하는 방법은 아래와 같다.
# ``` python
#     import string
#     print(string.punctuation)
# ```
# - 요구사항 2. 만약 punctuation (구두문자)를 제거한 이후 공백으로 판명되는 단어들은 해당 단어 리스트에서 제거하시오.
#     - 예: ['컴퓨터공학부!', '---?', '%지향~', '...'] ---> ['컴퓨터공학부', '지향']
# - 요구사항 3. 각 단어들의 출현빈도를 사전형태로 저장하여 출력하시오.
#     - 예: ['world', 'hello', 'python', 'world', '컴퓨터공학부', '지향'] ---> {'world': 2, 'hello': 1, 'python': 1, '컴퓨터공학부': 1, '지향': 1}
# - 요구사항 4. 다음 3개의 사이트에 대한 결과를 출력하시오.
#     - http://www.naver.com
#     - http://www.daum.net
#     - http://www.nytimes.com

# %%
import string
from urllib import request 

#urls = ['http://edition.cnn.com/','https://www.nytimes.com/', 'http://abcnews.go.com/', 'http://www.reuters.com/']
urls = ['http://edition.cnn.com/','https://www.nytimes.com/', 'http://abcnews.go.com/','http://www.reuters.com/','https://www.washingtonpost.com/', \
        'https://techcrunch.com/', 'https://www.techinasia.com/', 'https://www.bloomberg.com/asia']
stopword = []
with open('stopword.txt', 'r') as f:
    for line in f:
        if(line != "\n") :
            stopword.append(line.strip())
stopword.append("nbsp") 
stopword.append("lt") 
stopword.append("gt") 
stopword.append("amp") 
stopword.append("quot") 
stopword.append("pm") 
stopword.append("et") 
stopword.append("est")

                
for url in urls:
    total_word = 0
    words = []
    dic = {}
    javascript_check = False
    css_check = False

    f = request.urlopen(url)
    source_bytes = f.read()
    source = source_bytes.decode('utf-8')

    for i in source.split("<"):
        m = i.split(">")
        #print(m)
        
        if len(m) > 1:
            check = m[0].split()
            #if('script' in m[0] and m[0].find("description") == -1 and m[0].find("subscription") == -1 and m[0].find("transcript") == -1 and m[0].find(" javascript:void();") == -1): javascript_check = True 
            if('script' == check[0]): javascript_check = True
            if('/script' in m[0]): javascript_check = False  
            #if(m[0].find('style') != -1 and m[0].find('style=') == -1 and m[0].find('stylesheet') == -1and m[0].find('Lifestyle') == -1): css_check = True   
            if('style' == check[0]): css_check = True 
            if('/style' in m[0]): css_check = False
            #print(javascript_check, css_check)
            m = m[1].strip().lower()
            if(m != "" and not javascript_check and not css_check):
                rep = ["//","--",'\'', '$','©','&', '%', '"', '^', 'ⓒ', '·','…', '—', '~', '–', '»', '!','”', '㈜', '-', '/', ':', '(', ')', '[', ']', '_','“', '‘', '’', '.', ',']
                rep = rep + list(string.punctuation)      
                rep = list(set(rep))
                for r in rep:
                    m = m.replace(r, ' ')
                m = m.split()
                #print(m)
                for n in m:
                    if(n != ''): 
                        if(n.isdigit()): continue
                        else:
                            if(n not in stopword):
                                total_word += 1
                                words.append(n.strip())
                                #print(n.strip())
    for i in words:
        if(i not in dic):
            dic[i] = 1
        else:
            dic[i] = dic[i] + 1
   
    items = list(dic.items())
    items.sort(key=lambda d: d[1], reverse=True)
    for k,v in items:
        print(k,v)
    print()
# Out:
# cnn 12
# international 11
# video 8
# edition 7
# news 7
# tv 5
# luxury 4
# preference 4
# set 4
# arabic 4
# culture 4
# features 4
# business 4
# africa 4
# confirm 4
# weather 3
# tech 3
# regions 3
# health 3
# sport 3
# home 3
# world 3
# vr 3
# politics 3
# español 3
# entertainment 2
# ireport 2
# parenting 2
# food 2
# motorsport 2
# trumpmerica 2
# diet 2
# americas 2
# screen 2
# china 2
# sites 2
# play 2
# arts 2
# skiing 2
# equestrian 2
# hln 2
# network 2
# signs 2
# tennis 2
# videos 2
# watch 2
# feature 2
# copy 2
# freedom 2
# inside 2
# leadership 2
# architecture 2
# fashion 2
# worldwide 2
# degrees 2
# congress 2
# nine 2
# middle 2
# impact 2
# opinion 2
# markets 2
# horse 2
# partner 2
# security 2
# racing 2
# vital 2
# design 2
# stars 2
# profiles 2
# east 2
# archives 2
# future 2
# cable 2
# gadgets 2
# destinations 2
# drink 2
# heroes 2
# startups 2
# asia 2
# binge 2
# stay 2
# media 2
# pressroom 2
# family 2
# schedule 2
# living 2
# autos 2
# ...

# %% [markdown]
# #### 해설 : Incremental Project

# %% [markdown]
# 먼저 여기에서는 한 사이트만 예시로 들기 위해 변수들을 초기화해줍니다. 여러 사이트를 하려면 for ~ in과 사이트 주소가 저장되어 있는 list를 이용하면 됩니다. 그리고 url에 접속해서 나온 소스코드들을 string으로 변환한 다음 이를 "<"로 split을 사용하여 나눠줍니다.

# %%
total_word = 0
words = []
dic = {}
javascript_check = False
css_check = False
url = "http://www.naver.com"

f = request.urlopen(url)
source_bytes = f.read()
source = source_bytes.decode('utf-8')

print(source.split("<"))
# Out:
# ['', '!doctype html>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n', 'html lang="ko" class="svgless">\n', 'head>\n', 'meta charset="utf-8">\n', 'meta name="Referrer" content="origin">\n', 'meta http-equiv="Content-Script-Type" content="text/javascript">\n', 'meta http-equiv="Content-Style-Type" content="text/css">\n', 'meta http-equiv="X-UA-Compatible" content="IE=edge">\n', 'meta name="viewport" content="width=1100">\n', 'meta name="apple-mobile-web-app-title" content="NAVER" />\n', 'meta name="robots" content="index,nofollow"/>\n', 'meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>\n', 'meta property="og:title" content="네이버">\n', 'meta property="og:url" content="http://www.naver.com/">\n', 'meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png">\n', 'meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>\n', 'meta name="twitter:card" content="summary">\n', 'meta name="twitter:title" content
# ...

# %% [markdown]
# 그리고 이 상태에서 for문을 이용해 하나씩 분리시킨 다음 이를 또 ">"로 split을 하게 되면 다음과 같이 나옵니다.

# %%
for i in source.split("<"):
    m = i.split(">")
    print(m)
# Out:
# ['']
# ['!doctype html', '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n']
# ['html lang="ko" class="svgless"', '\n']
# ['head', '\n']
# ['meta charset="utf-8"', '\n']
# ['meta name="Referrer" content="origin"', '\n']
# ['meta http-equiv="Content-Script-Type" content="text/javascript"', '\n']
# ['meta http-equiv="Content-Style-Type" content="text/css"', '\n']
# ['meta http-equiv="X-UA-Compatible" content="IE=edge"', '\n']
# ['meta name="viewport" content="width=1100"', '\n']
# ['meta name="apple-mobile-web-app-title" content="NAVER" /', '\n']
# ['meta name="robots" content="index,nofollow"/', '\n']
# ['meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/', '\n']
# ['meta property="og:title" content="네이버"', '\n']
# ['meta property="og:url" content="http://www.naver.com/"', '\n']
# ['meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"', '\n']
# ...

# %% [markdown]
# 이렇게 되면 배열마다 m[0]은 tag 안의 내용으로, m[1]은 태그 밖의 내용이 나옵니다.
# 그리고 여기에서 javascript와 CSS를 빼기 위해 m[0]에 'script'가 있으면 자바스크립트 부분이 시작된다고 해서 javascript_check를 true로 바꿔준 후, m에 대해 검사할 때 이것이 true가 되면 그 줄은 그냥 사용하지 않는 것으로 합니다. 하지만 m[0]에 '/script'가 들어가면 자바스크립트 부분이 종료된다고 해서 javascript_check를 false로 바꿔 준 후에 m에서 검사할 때 정상적으로 그 부분 부터 다시 사용할 수 있게 합니다. CSS도 마찬가지로 'style type="text/css"'가 들어가면 css_check를 true로, '/style'이 나오면 css_check를 false로 해주면서 아까와 같이 필터링을 해줍니다.
#
# 이렇게 하면 일단 HTML 태그, javascript, css를 제외한 순수 텍스트 문자열은 받게 됩니다. 그러나, 이 과제에서는 순수 텍스트 문자에서 단어의 갯수를 알아내야 하는데, 여기에서 특수문자를 제외해야합니다. 그래서 과제 2에서 만든 특수문자 모음에 String에 포함되어있는 punctuation단어를 모두 포함해서 중복되는 부분은 지워줍니다. 이는 set을 이용해서 중복을 삭제하고 다시 list로 변경하였습니다. 그 다음 특수문자를 하나씩 제거하는데, 단어 구분을 위해 특수문자들은 띄어쓰기(" ")로 바꾸기로 하였습니다. 그 다음에 띄어쓰기(" ")로 split을 하면 이제 한 단어마다 list에 저장이 됩니다. 그럼 이제 비어있는 값과 숫자를 빼면 한 단어씩 출력이 됩니다.

# %%
words = []
dic = {}
for i in source.split("<"):
    m = i.split(">")
        
    if('script' in m[0]): javascript_check = True    
    if('/script' in m[0]): javascript_check = False  
    if('style type="text/css"' in m[0]): css_check = True   
    if('/style' in m[0]): css_check = False
                
    if len(m) > 1:
        m = m[1].strip()
        if(m != "" and not javascript_check and not css_check):
            rep = ["//","--",'\'', '$','©','&', '%', '"', '^', 'ⓒ', '·','…', '~', '!','”', '㈜', '-', '/', ':', '(', ')', '[', ']', '_','“', '‘', '’', '.', ',']
            rep = rep + list(string.punctuation)
            rep = list(set(rep))
            for r in rep:
                m = m.replace(r, ' ')
            m = m.split()
            for n in m:
                if(n != ''): 
                    if(n.isdigit()): continue
                    else:
                        total_word += 1
                        words.append(n.strip())
                        print(n.strip())
# Out:
# NAVER
# 뉴스스탠드
# 바로가기
# 주제별캐스트
# 바로가기
# 타임스퀘어
# 바로가기
# 쇼핑캐스트
# 바로가기
# 로그인
# 바로가기
# 네이버
# 네이버를
# 시작페이지로
# 쥬니어네이버
# 해피빈
# 검색
# 통합검색
# 블로그
# 카페
# 카페명
# 카페글
# 지식iN
# 뉴스
# 사이트
# 카테고리
# 사이트
# 영화
# 웹문서
# 사전
# 백과사전
# 영어사전
# 영영사전
# 국어사전
# 일본어사전
# 한자사전
# 용어사전
# 책
# 음악
# 전문자료
# 쇼핑
# 지역
# 동영상
# 이미지
# 내PC
# 영화
# 자동차
# 게임
# 건강
# 인물
# 긍정부정검색
# 메일
# 카페
# 블로그
# 지식인
# 쇼핑
# 네이버페이
# 네이버TV
# 사전
# 뉴스
# 증권
# 금융
# 부동산
# 지도
# 영화
# 뮤직
# 책
# 만화
# 웹툰
# 더보기
# 실시간
# 급상승
# 검색어
# 고영주
# 카탈루냐
# 소사이어티
# 게임
# 더
# 서울어워즈
# 장기용
# 알쓸신잡2
# 박광재
# 가결
# 백종원의
# 푸드트럭
# 고보결
# 할로윈데이
# 팬텀싱어2
# 홍종학
# 유승옥
# 한국전력공사
# 채용
# 고백부부
# 공인중개사
# 시험
# 호랑이형님
# 이영학
# 메가박스
# 실시간
# 급상승
# DataLab
# 급상승
# 트래킹
# 10위
# 20위
# 고영주
# 데이터랩
# 그래프
# 보기
# 카탈루냐
# 데이터랩
# 그래프
# 보기
# 소사이어티
# 게임
# 데이터랩
# 그래프
# 보기
# 더
# 서울어워즈
# 데이터랩
# 그래프
# 보기
# 장기용
# 데이터랩
# 그래프
# 보기
# 알쓸신잡2
# 데이터랩
# 그래프
# 보기
# 박광재
# 데이터랩
# 그래프
# 보기
# 가결
# 데이터랩
# 그래프
# 보기
# 백종원의
# 푸드트럭
# 데이터랩
# 그래프
# 보기
# 고보결
# 데이터랩
# 그래프
# 보기
# 할로윈데이
# 데이터랩
# 그래프
# 보기
# 팬텀싱어2
# 데이터랩
# 그래프
# 보기
# 홍종학
# 데이터랩
# 그래프
# ...

# %% [markdown]
# 이제 이 list를 dictionary로 변환하기 위해, words에 저장되어 있는 단어를 하나씩 가져와서 dic에 없는 단어면 key는 단어로 하는 객체에 값은 1로 추가해주고 dic에 있는 단어이면 1씩 더해줍니다. 이렇게 하면 다음과 같이 dictionary 형태로 변환됩니다.

# %%
for i in words:
    if(i not in dic):
        dic[i] = 1
    else:
        dic[i] = dic[i] + 1
   
print(dic)
# Out:
# {'NAVER': 3, '뉴스스탠드': 2, '바로가기': 7, '주제별캐스트': 1, '타임스퀘어': 1, '쇼핑캐스트': 2, '로그인': 3, '네이버': 7, '네이버를': 1, '시작페이지로': 1, '쥬니어네이버': 1, '해피빈': 1, '검색': 1, '통합검색': 1, '블로그': 16, '카페': 2, '카페명': 1, '카페글': 1, '지식iN': 1, '뉴스': 3, '사이트': 2, '카테고리': 1, '영화': 4, '웹문서': 1, '사전': 2, '백과사전': 1, '영어사전': 1, '영영사전': 1, '국어사전': 1, '일본어사전': 1, '한자사전': 1, '용어사전': 1, '책': 2, '음악': 1, '전문자료': 1, '쇼핑': 2, '지역': 2, '동영상': 1, '이미지': 1, '내PC': 1, '자동차': 2, '게임': 4, '건강': 2, '인물': 1, '긍정부정검색': 1, '메일': 1, '지식인': 1, '네이버페이': 1, '네이버TV': 1, '증권': 1, '금융': 1, '부동산': 1, '지도': 1, '뮤직': 2, '만화': 1, '웹툰': 2, '더보기': 1, '실시간': 2, '급상승': 3, '검색어': 1, '고영주': 2, '카탈루냐': 3, '소사이어티': 2, '더': 3, '서울어워즈': 2, '장기용': 2, '알쓸신잡2': 2, '박광재': 2, '가결': 2, '백종원의': 2, '푸드트럭': 2, '고보결': 2, '할로윈데이': 2, '팬텀싱어2': 2, '홍종학': 3, '유승옥': 2, '한국전력공사': 2, '채용': 2, '고백부부': 2, '공인중개사': 2, '시험': 2, '호랑이형님': 2, '이영학': 2, '메가박스': 2, 'DataLab': 1, '트래킹': 1, '10위': 1, '20위': 1, '데이터랩': 20, '그래프': 20, '보기': 20, '기준': 1, '도움말': 1, '연합뉴스': 1, '이진성': 1, '헌재소
# ...

# %% [markdown]
# #### 추가 : 많이 나온 글자 순으로 정렬

# %% [markdown]
# 문제 7에서 했었던 값에 대한 정렬을 사용해서 여기에 적용해보았습니다. 정렬 결과는 다음과 같았습니다.

# %%
items = list(dic.items())
items.sort(key=lambda d: d[1], reverse=True)
for k,v in items:
    print(k,v)
# Out:
# 데이터랩 20
# 그래프 20
# 보기 20
# 구독 19
# 해지 18
# 기사보기 18
# 블로그 16
# 주제 8
# 바로가기 7
# 네이버 7
# 스포츠 5
# 언론사 5
# 영화 4
# 게임 4
# 관심 4
# NAVER 3
# 로그인 3
# 뉴스 3
# 급상승 3
# 카탈루냐 3
# 더 3
# 홍종학 3
# 전체 3
# 설정 3
# 목록 3
# Sign 3
# 비즈니스 3
# 신혼집 3
# 뉴스스탠드 2
# 쇼핑캐스트 2
# 카페 2
# 사이트 2
# 사전 2
# 책 2
# 쇼핑 2
# 지역 2
# 자동차 2
# 건강 2
# 뮤직 2
# 웹툰 2
# 실시간 2
# 고영주 2
# 소사이어티 2
# 서울어워즈 2
# 장기용 2
# 알쓸신잡2 2
# 박광재 2
# 가결 2
# 백종원의 2
# 푸드트럭 2
# 고보결 2
# 할로윈데이 2
# 팬텀싱어2 2
# 유승옥 2
# 한국전력공사 2
# 채용 2
# 고백부부 2
# 공인중개사 2
# 시험 2
# 호랑이형님 2
# 이영학 2
# 메가박스 2
# 연예 2
# 경제 2
# 이전 2
# 페이지 2
# 다음 2
# 설정한 2
# in 2
# 목록으로 2
# 이동 2
# 리빙 2
# 모바일 2
# 가져오기 2
# 후 2
# 사용 2
# 가능합니다 2
# 인테리어 2
# 꾸미기 2
# 안내 2
# 프로젝트 2
# 꽃 2
# 스피커 2
# 정책 2
# 주제별캐스트 1
# 타임스퀘어 1
# 네이버를 1
# 시작페이지로 1
# 쥬니어네이버 1
# 해피빈 1
# 검색 1
# 통합검색 1
# 카페명 1
# 카페글 1
# 지식iN 1
# 카테고리 1
# 웹문서 1
# 백과사전 1
# 영어사전 1
# 영영사전 1
# 국어사전 1
# 일본어사전 1
# 한자사전 1
# 용어사전 1
# 음악 1
# 전문자료 1
# 동영상 1
# 이미지 1
# 내PC 1
# 인물 1
# 긍정부정검색 1
# 메일 1
# 지식인 1
# 네이버페이 1
# 네이버TV 1
# 증권 1
# 금융 1
# 부동산 1
# 지도 1
# 만화 1
# 더보기 1
# ...

# %% [markdown]
# -----------------------------------

# %% [markdown]
# ## 느낀 점

# %% [markdown]
# 이번 과제는 리스트, 문자열, 사전 등을 중심으로 다룬 과제였습니다. 점점 파이썬이 내부에서 어떻게 돌아가는지 보면서 흥미로운 것 같습니다. 예전엔 단순히 파이썬은 쉬운 언어다 싶었는데, 메모리적인 관점에서 바라봤을 때 독특하게 운영되는 것이 신기합니다. 그리고 이번에 사전의 값에 따른 sort를 찾다가 lambda란 문법을 발견했는데, 확실히 기존 함수를 더 간략하게 표현할 수 있다는 것이 좋은 것 같습니다. 그리고 sort 함수 내에 key를 설정해서 sort가 가능한 것을 보면서 sort란 함수안에는 for문을 이용해서 작동하는 것 같았습니다. 그 때 교수님이 얘기해주셨던 얘기중에 "사전은 sort를 하지 않는 게 좋다"라고 하셨는데, 그 이유를 생각해보면 사전 객체의 목적은 어떤 것을 정렬하는 목적이 아니라 어떤 키를 주면 해당하는 값을 빨리 찾아주는 것이 목적이기 때문이라고 생각했습니다. 굳이 정렬을 한다면 사전보다는 리스트가 더 적합한 객체라서 그런 것 같습니다. 그리고 네이버를 크롤링하면서 느낀 점은 네이버는 대부분 정보를 가져오는 데 javascript로 정보를 가져온다는 것을 알 수 있었습니다. 그래서 예상 외로 네이버에서 javascript를 제외하면 네이버에 들어갈 때 보여주는 단어의 갯수에 비해서 많은 단어를 갖고 있지 않은 것 같습니다. 이것이 웹에서 효율적인 구조인 것이, html에서 반복적인 부분은 javascript나 python같은 스크립트 언어로 for문을 사용해서 일괄적으로 구조를 만들어주는 것이 불필요한 코드를 줄여줄 수 있어서 네이버에서도 이러한 방식을 사용하는 것 같습니다. 그리고 javascript와 css를 제외하는 방법으로 특정 문장이 포함되어있을 때 다른 특정 부분이 나오기 전까지 그 부분을 제외하는 걸로 구현하였는데, 이는 너무 비효율적이고 모든 상황에 들어맞지는 않아서 더 효율적인 방법이 무엇이 있는지 잘 모르겠습니다. 그래도 파이썬을 하면서 예전에 배웠던 ruby와 비교하면 서로의 장단점이 있는 것 같고, 파이썬의 내부 구조를 보면서 ruby의 내부 구조는 파이썬이랑 다른지도 궁금할 때도 있습니다. 또한 ruby와 python을 하다보면 문법이 헷갈릴 때도 있습니다. 예를 들면 이번 ACM-ICPC문제를 한번 python과 ruby로 둘다 풀어봤는데 리스트(루비는 Array)의 길이를 구하는 게 약간씩 다르고, 그래서 오류가 생길 때 한번에 인지하지 못할 때도 있습니다. 그래도 두 언어의 속도나 이런 점을 비교하면 파이썬이 조금 더 유리하다는 생각이 들었습니다. 이번에 이 두 언어를 비교하면서 배우는 것도 도움이 될 것 같습니다.
