# %%
import string
from urllib import request
import pickle

directory = "C:\\Users\\wxg12\\PycharmProjects\\python_lecture\\test"

stopword = []
num = 0
with open('stopword.txt', 'r') as f:
    for line in f:
        if (line != "\n"):
            stopword.append(line.strip())
stopword.append("nbsp")
stopword.append("lt")
stopword.append("gt")
stopword.append("amp")
stopword.append("quot")
stopword.append("pm")
stopword.append("et")
stopword.append("est")

with open('print.txt', 'w') as p:
    # urls = ['http://edition.cnn.com/', 'https://www.nytimes.com/', 'http://abcnews.go.com/', 'http://www.reuters.com/','https://www.washingtonpost.com/','https://techcrunch.com/', 'https://www.bloomberg.com/asia', 'https://thenextweb.com/','https://www.theverge.com/', 'http://fortune.com/']
    urls = ['www.cnn.com', 'www.nytimes.com', 'abcnews.go.com', 'www.reuters.com',
            'www.theverge.com']

    for url in urls:
        total_word = 0
        words = []
        dic = {}
        javascript_check = False
        css_check = False

        f = request.urlopen('http://' + url)
        source_bytes = f.read()
        source = source_bytes.decode('utf-8')
        with open(str(url) + '.html', "w") as html:
            html.write(source)

        for i in source.split("<"):
            m = i.split(">")
            print(m)
            p.write(str(m))
            p.write("\n")

            if len(m) > 1:
                check = m[0].split()
                if len(check) > 0:
                    # if('script' in m[0] and m[0].find("description") == -1 and m[0].find("subscription") == -1 and m[0].find("transcript") == -1 and m[0].find(" javascript:void();") == -1): javascript_check = True
                    if ('script' == check[0]): javascript_check = True
                    if ('/script' in m[0]): javascript_check = False
                    # if(m[0].find('style') != -1 and m[0].find('style=') == -1 and m[0].find('stylesheet') == -1and m[0].find('Lifestyle') == -1): css_check = True
                    if ('style' == check[0]): css_check = True
                    if ('/style' in m[0]): css_check = False
                    print(javascript_check, css_check)
                    p.write(str(javascript_check) + " " + str(css_check))
                    p.write("\n")
                    m = m[1].strip().lower()
                    if (m != "" and not javascript_check and not css_check):
                        rep = ["//", "--", '\'', '$', '©', '&', '%', '"', '^', 'ⓒ', '·', '…', '—', '~', '–', '»', '!',
                               '”', '㈜', '-', '/', ':', '(', ')', '[', ']', '_', '“', '‘', '’', '.', ',']
                        rep = rep + list(string.punctuation)
                        rep = list(set(rep))
                        for r in rep:
                            m = m.replace(r, ' ')
                        m = m.split()
                        # print(m)
                        for n in m:
                            if (n != ''):
                                if (n.isdigit()):
                                    continue
                                else:
                                    if (n not in stopword):
                                        total_word += 1
                                        words.append(n.strip())
                                        # print(n.strip())
        for i in words:
            if (i not in dic):
                dic[i] = 1
            else:
                dic[i] = dic[i] + 1


        items = list(dic.items())
        items.sort(key=lambda d: d[1], reverse=True)

        with open(str(url) + '.words.frequency', 'wb') as plk:
            pickle.dump(items, plk)
        num = num + 1

        for k, v in items:
            print(k, v)
            p.write(str(k) + " " + str(v))
            p.write("\n")
        print()
        p.write("\n")
        p.write("\n")
# Out:
# ['']
# ['!DOCTYPE html', '']
# False False
# ['html class="no-js"', '']
# False False
# ['head', '']
# False False
# ['meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"', '']
# False False
# ['meta charset="utf-8"', '']
# False False
# ['meta content="text/html" http-equiv="Content-Type"', '']
# False False
# ['meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0"', '']
# False False
# ['script type="text/javascript" async="false"', '(function(win, doc) {var bannerElement;win.enableSmartBannerTracking = false;if (typeof navigator.userAgent === \'string\' && navigator.userAgent.search(/(iPhone|iPad|iPod);/) !== -1 &&typeof doc.cookie === \'string\' && doc.cookie.search(/(^|;)\\s*CNNtosAgreed=[^;]+/) !== -1) {bannerElement = doc.createElement(\'meta\');win.enableSmartBannerTracking = true;bannerElement.name = "apple-itunes-app";bannerElement.content = "app-id=331786748";doc.getElementsByTagName(\'head\')[0].appendChild(bannerElement);}}(window, document));']
# True False
# ['/script', '']
# False False
# ['link href="/favicon.ie9.ico" rel="Shortcut Icon" type="image/x-icon"/', '']
# False False
# ['link href="//cdn.cnn.com/cnn/.e/img/3.0/global/misc/apple-touch-icon.png" rel="apple-touch-icon" type="image/png"/', '']
# False False
# ['!--[if lte IE 9]', '']
# False False
# ['meta http-equiv="refresh" content="1;url=/2.49.5/static/unsupp.html" /', '']
# False False
# ['![endif]--', '']
# False False
# ['!--[if gt IE 9', '']
# False False
# ['!--', '']
# False False
# ['script', 'var CNN = CNN || {};CNN.pageTimer = {"interval":20,"isVisible":true,"pageType":"section","resetDelay":3,"resetThreshold":17,"sectionName":"intl_homepage"};']
# True False
# ['/script', '']
# False False
# ['!--']
# ['![endif]--', '']
# False False
# ['title', 'CNN - Breaking News, U.S., World, Weather, Entertainment & Video News']
# False False
# ['/title', '']
# False False
# ['meta content="intl_homepage" name="section"', '']
# False False
# ['meta content="2014-02-24T14:45:54Z" property="og:pubdate"', '']
# False False
# ['meta content="2014-02-24T14:45:54Z" name="pubdate"', '']
# False False
# ['meta content="2017-11-19T13:43:01Z" name="lastmod"', '']
# False False
# ['meta content="http://www.cnn.com" property="og:url"', '']
# False False
# ['meta content="CNN - Breaking News, U.S., World, Weather, Entertainment &amp; Video News" property="og:title"', '']
# False False
# ['meta content="CNN - Breaking News, U.S., World, Weather, Entertainment &amp; Video News" name="twitter:title"', '']
# False False
# ['meta content="Find the latest breaking news and information on the top stories, weather, business, entertainment, politics, and more. For in-depth coverage, CNN provides special reports, video, audio, photo galleries, and interactive guides." property="og:description"', '']
# False False
# ['meta content="Find the latest breaking news and information on the top stories, weather, business, entertainment, politics, and more. For in-depth coverage, CNN provides special reports, video, audio, photo galleries, and interactive guides." name="description"', '']
# False False
# ['meta content="Find the latest breaking news and information on the top stories, weather, business, entertainment, politics, and more. For in-depth coverage, CNN provides special reports, video, audio, photo galleries, and interactive guides." name="twitter:description"', '']
# False False
# ['meta content="breaking news, news online, U.S. news, world news, developing story, news video, CNN news, weather, business, money, politics, law, technology, entertainment, education, travel, health, special reports, autos, CNN TV" name="keywords"', '']
# False False
# ['meta content="CNN" property="og:site_name"', '']
# False False
# ['meta content="summary_large_image" name="twitter:card"', '']
# False False
# ['meta content="website" property="og:type"', '']
# False False
# ['meta property="vr:canonical" content="http://edition.cnn.com"', '']
# False False
# ['link rel="alternate" href="http://edition.cnn.com" hreflang="en-gb"', '']
# False False
# ['link rel="alternate" href="http://edition.cnn.com" hreflang="en"', '']
# False False
# ['link rel="alternate" href="http://www.cnn.com" hreflang="en-us"', '']
# False False
# ['link rel="alternate" href="http://www.cnn.com" hreflang="en-ca"', '']
# False False
# ['meta content="80401312489" property="fb:app_id"', '']
# False False
# ['meta content="5550296508,18793419640" property="fb:pages"', '']
# False False
# ['link rel="canonical" href="http://www.cnn.com"', '']
# False False
# ['link rel="publisher" href="https://plus.google.com/+cnn/posts" /', '']
# False False
# ['link rel="alternate" href="android-app://com.cnn.mobile.android.phone/http/www.cnn.com" /', '']
# False False
# ['link rel="dns-prefetch" href="//cdn.optimizely.com/js/128727546.js" /', '']
# False False
# ['link rel="dns-prefetch" href="//tpc.googlesyndication.com" /', '']
# False False
# ['link rel="dns-prefetch" href="//pagead2.googlesyndication.com" /', '']
# False False
# ['link rel="dns-prefetch" href="//www.googletagservices.com" /', '']
# False False
# ['link rel="dns-prefetch" href="//partner.googleadservices.com" /', '']
# False False
# ['link rel="dns-prefetch" href="//www.google.com" /', '']
# False False
# ['link rel="dns-prefetch" href="//aax.amazon-adsystem.com" /', '']
# False False
# ['link rel="dns-prefetch" href="//cdn.krxd.net" /', '']
# False False
# ['link rel="dns-prefetch" href="//segment-data-us-east.zqtk.net/turner-47fcf6" /', '']
# False False
# ['link rel="dns-prefetch" href="//ads.rubiconproject.com" /', '']
# False False
# ['link rel="dns-prefetch" href="//optimized-by.rubiconproject.com" /', '']
# False False
# ['link rel="dns-prefetch" href="//fastlane.rubiconproject.com" /', '']
# False False
# ['link rel="dns-prefetch" href="//fastlane-adv.rubiconproject.com" /', '']
# False False
# ['link rel="dns-prefetch" href="//a.postrelease.com/serve/load.js?async=true" /', '']
# False False
# ['link rel="dns-prefetch" href="//w.usabilla.com" /', '']
# False False
# ['link rel="dns-prefetch" href="//s.skimresources.com/js/87760X1540660.skimlinks.js" /', '']
# False False
# ['link rel="dns-prefetch" href="" /', '']
# False False
# ['link rel="dns-prefetch" href="//weather.api.cnn.io" /', '']
# False False
# ['link rel="dns-prefetch" href="//pmd.cdn.turner.com" /', '']
# False False
# ['link rel="dns-prefetch" href="//ht.cdn.turner.com" /', '']
# False False
# ['link rel="dns-prefetch" href="//www.ugdturner.com" /', '']
# False False
# ['link rel="dns-prefetch" href="//vrt.outbrain.com" /', '']
# False False
# ['link rel="dns-prefetch" href="//consent.truste.com" /', '']
# False False
# ['link rel="dns-prefetch" href="//data.cnn.com" /', '']
# False False
# ['link rel="dns-prefetch" href="//cdn.cnn.com" /', '']
# False False
# ['link rel="dns-prefetch" href="//edition.i.cdn.cnn.com" /', '']
# False False
# ['link rel="stylesheet" href="http://edition.cnn.com/css/2.49.5/global.css"', '']
# False False
# ['link rel="stylesheet" href="http://edition.cnn.com/css/2.49.5/pages/page.css"', '']
# False False
# ['script', "if ((typeof window.innerHeight === 'number' && window.innerHeight "]
# True False
# [' 0 && window.innerHeight ', "= 0)||(typeof document.location.href === 'string' && document.location.href.search(/^http(?:s)?:\\/\\/edition\\.cnn\\.com\\/\\?\\d+$/i) !== -1)) {if (typeof window.stop === 'function') {window.stop();} else {document.execCommand('Stop');}}"]
# True False
# ['/script', '']
# False False
# ['script', 'var CNN = CNN || {},CNNI = CNNI || {},FAVE = FAVE || {};window.document.domain = \'cnn.com\';if (typeof window.console === \'undefined\') {window.console = {debug: function() {return true;},error: function() {return true;},info: function() {return false;},warn: function() {return false;},log: function() {return false;},timeStamp: function() {return false;}}}CNNI.adTargets = {protocol: "non-ssl"};CNN.AdsConfig = {enableAdLock: false,enableGalleryAdRefresh:true,galleryAdClicks: 4, amazon: {"amznkey":"3288"}, companionAdStates: [{"label":"small","minWidth":0},{"label":"large","minWidth":768}], desktopSSID: \'edition.cnn.com_main_homepage\', mobileSSID: \'edition.cnn.com_mobile_mobileweb_homepage\', fwNetworkId: 48804, fwProfile: \'cnn_mobile_web_linktag2\'};CNN.analyticsConfig = {"rollups":{}};CNN.BannerBreakpoints = "c0.0:0, c8.5:600, c9.5:680, c10.5:760, c11.5:840, c12.5:920, c13.5:1000, c14.5:1080";CNN.CNNXStreamUrl = "http://go.cnn.com/?stream=";CNN.DemandLoadConfig = {"enableForCarousels":true,"enableForImages":true,"loadTimeOut":5000,"threshold":300};CNN.Edition = "international";CNN.EditionCookie = "PreferredEdition";CNN.Features = {enableAdsConsole: true,enableAmazonDisplayAds: true,enableAppia: false,enableCriteoAds: false,enableEpicAds: true,enableFreewheel: true,enableGalleryAds: true,enableGigyaLogin: true,enableIndexExchange: true,enableIntegralAdScience: true,enableInViewRefresh: true,enableKrux: true,enableLiveFyre: true,enableProximic: true,enableRubiconFastlane: true,enableSourcePoint: false,enableAmazonVideoAds: true,enableAspen: true,enableAspenForTOS: true,enableBreakingNews: true,enableChartbeat: true,enableChartbeatMAB: true,enableContainerInjection: false,enableFave: true,enableJumbotronAutoScroll: false,enableLiveVideoGeoCheck: false,enableOmniture: true,enableOneTapToPlay: true,enableOneTapNativeFullscreen: false,enableOutbrainOneTapToPlay: true,enableOptimizely: true,enableOutbrain: true,enableOutbrainVideoKPI: true,enableZoneOutbrain: true,enablePiiAdFilter: true,enableRefreshTimers: true,enableSafariPushAlerts: false,enableShareButtons: true,enableTiming: true,enableUserMessage: true,enableVideoEndSlate: true,enableVideoExperienceUnification: true,enableVideoExperienceUnificationVideoPinning: true,enableVideoPinning: true,enableVisualRevenueVideo: false,enableWeather: true};CNN.Chartbeat = {"MABsrc":"//static.chartbeat.com/js/chartbeat_mab.js","src":"//static.chartbeat.com/js/chartbeat.js","uid":37612};CNN.Feeds = {"breakingNews":{"ttl":120000,"url":"//data.cnn.com/jsonp/breaking_news/international.json"}};CNN.GoFreePreviewConfig = {"adobeEnvironment":"prod","adobeSwfPath":"/.element/apps/cvp/3.0/swf/AccessEnablerLoader.swf","aspenContext":"prev10","endSlate":{"ctaText":"Sign in to your TV Service Provider","messageText":"Keep watching CNN anytime, anywhere with CNNgo.\\u003cbr/', 'Sign in to your TV service provider to get access to\\u003cbr/', 'all of your favorite CNN shows and specials.","titleText":"Your CNNgo preview has expired"},"errorSlate":{"defaultText":"An error has occurred. Click OK to refresh.","subscriptionErrorText":"Your pay TV subscription does not include CNN. Please contact your TV Service Provider.","troubleShootingText":"If error persists, see \\u003ca href=\\"//www.cnn.com/help/cnngo-troubleshooting.html\\" class=\\"troubleshooting-link\\" target=\\"_blank\\"', 'troubleshooting instructions.\\u003c/a', '"},"goSmartLink":"http://cnn.it/go","helpLink":"//edition.cnn.com/help","persistentCta":{"cobrandingText":"In partnership with","countdownText":"Preview expires in","persistentCtaText":"Experience"},"removeMinimumDimensionsTimeout":1500,"temppass":"TempPass_CNN10min"};CNN.Host = {assetPath: "http://edition.i.cdn.cnn.com/.a/2.49.5",alt: "",chrome: "//cdn.cnn.com/cnn",cssPath: "/css/2.49.5",domain: "http://edition.cnn.com",main: "edition.cnn.com",sponsorContent: "http://s3.amazonaws.com/cnn-sponsored-content",protocol: "http",intl: "http://edition.cnn.com",nowPlaying: " ...
# True False
# ['/script', '']
# False False
# ['script src="//edition.i.cdn.cnn.com/.a/bundles/cnn-header.bb0d864591f5bdfc609e-first-bundle.js"', '']
# True False
# ['/script', '']
# False False
# ['script src="//edition.i.cdn.cnn.com/.a/2.49.5/js/cnn-header-second.min.js"', '']
# True False
# ['/script', '']
# False False
# ['!--[if lte IE 9]', '']
# False False
# ['script', "if (navigator.appVersion.indexOf('Windows Phone OS 7') ", " -1 || navigator.appVersion.indexOf('WP7') ", " -1) {var $html = document.getElementsByTagName('html')[0];Modernizr.load({test: Modernizr.fontface,complete: function () {'use strict';$html.className = $html.className.replace(/\\bfontface\\b/, 'no-fontface');}});}"]
# True False
# ['/script', '']
# False False
# ['![endif]--', '']
# False False
# ['script', 'try {window.performance.mark("optimizelyStart");} catch (err) {}']
# True False
# ['/script', '']
# False False
# ['script src="//cdn.optimizely.com/js/128727546.js"', '']
# True False
# ['/script', '']
# False False
# ['script', 'try {window.performance.mark("optimizelyEnd");} catch (err) {}']
# True False
# ['/script', '']
# False False
# ['script', 'try {window.performance.mark("headEnd");} catch (err) {}']
# True False
# ['/script', '']
# False False
# ['/head', '']
# False False
# ['body class="pg pg-hidden pg-intl_homepage pg-section international t-light" data-eq-pts="xsmall: 0, medium: 460, large: 780, full16x9: 1100"', '']
# False False
# ['div class="ad ad--epic ad--all"', '']
# False False
# ['div id="ad_bnr_atf_02" class="ad-ad_bnr_atf_02 ad-refresh-adbody"', '']
# False False
# ['/div', '']
# False False
# ['/div', '']
# False False
# ['div class="user-msg"', '']
# False False
# ['div class="user-msg--container"', '']
# False False
# ['div class="user-msg--header"', '']
# False False
# ['div class="user-msg--header-text js-user-msg--header-text"', '']
# False False
# ['/div', '']
# False False
# ['div class="user-msg--close js-user-msg--close"', '']
# False False
# ['/div', '']
# False False
# ['/div', '']
# False False
# ['div class="user-msg--body"', '']
# False False
# ['div class="user-msg--body-text js-user-msg--body-text"', '']
# False False
# ['/div', '']
# False False
# ['/div', '']
# False False
# ['/div', '']
# False False
# ['/div', '']
# False False
# ['div id="nav__plain-header" class="nav--plain-header"', '']
# False False
# ['div id="breaking-news" class="breaking-news__background"', '']
# False False
# ['div class="l-container"', '']
# False False
# ['div class="breaking-news"', '']
# False False
# ['div class="breaking-news__close-btn"', '']
# False False
# ['/div', '']
# False False
# ['div class="breaking-news__title"', '']
# False False
# ['span class="breaking-news__title-text"', 'Breaking News']
# False False
# ['/span', '']
# False False
# ['/div', '']
# False False
# ['div class="breaking-news__msg"', '']
# False False
# ['/div', '']
# False False
# ['/div', '']
# False False
# ['/div', '']
# False False
# ['/div', '']
# False False
# ['div id="nav" class="nav nav-index-0"', '']
# False False
# ['div class="nav__color-strip"', '']
# False False
# ['/div', '']
# False False
# ['div class="nav__container"', '']
# False False
# ['a href="/" id="logo" class="nav__logo"', '']
# False False
# ['/a', '']
# False False
# ['div class="nav-section"', '']
# False False
# ['div class="nav-section__name js-nav-section-name" data-analytics-header="main-menu_intl_homepage"', '']
# False False
# ['a href="/"', 'Home']
# False False
# ['/a', '']
# False False
# ['span class="nav-section__expand-icon"', '+']
# False False
# ['/span', '']
# False False
# ['/div', '']
# False False
# ['div id="nav-section-submenu" class="nav-section__submenu" data-analytics-header="main-menu_intl_homepage"', '']
# False False
# ['/div', '']
# False False
# ['div id="js-nav-section-article-title" class="js-nav-section-article-title nav-section__article-title"', '']
# False False
# ['/div', '']
# False False
# ['/div', '']
# False False
# ['div class="nav-menu-links"', '']
# False False
# ['a class="nav-menu-links__link" href="/regions" data-analytics-header="main-menu_intl_regions"', 'Regions']
# False False
# ['/a', '']
# False False
# ['a class="nav-menu-links__link" href="/politics" data-analytics-header="main-menu_politics"', 'U.S. Politics']
# False False
# ['/a', '']
# False False
# ['a class="nav-menu-links__link" href="http://money.cnn.com/INTERNATIONAL/" data-analytics-header="main-menu_money"', 'Money']
# False False
# ['/a', '']
# False False
# ['a class="nav-menu-links__link" href="/entertainment" data-analytics-header="main-menu_entertainment"', 'Entertainment']
# False False
# ['/a', '']
# False False
# ['a class="nav-menu-links__link" href="http://money.cnn.com/technology/" data-analytics-header="main-menu_tech"', 'Tech']
# False False
# ['/a', '']
# False False
# ['a class="nav-menu-links__link" href="/sport" data-analytics-header="main-menu_sport"', 'Sport']
# False False
# ['/a', '']
# False False
# ['a class="nav-menu-links__link" href="/travel" data-analytics-header="main-menu_intl_travel"', 'Travel']
# False False
# ['/a', '']
# False False
# ['a class="nav-menu-links__link" href="/style" data-analytics-header="main-menu_style"', 'Style']
# False False
# ['/a', '']
# False False
# ['a class="nav-menu-links__link" href="/health" data-analytics-header="main-menu_health"', 'Health']
# False False
# ['/a', '']
# False False
# ['a class="nav-menu-links__link" href="/videos" data-analytics-header="main-menu_intl_videos"', 'Video']
# False False
# ['/a', '']
# False False
# ['a class="nav-menu-links__link" href="/vr" data-analytics-header="main-menu_vr"', 'VR']
# False False
# ['/a', '']
# False False
# ['/div', '']
# False False
# ['a href="http://go.cnn.com/?stream=cnni&sr=watchLiveHPbutton&source=edition" data-header="live" class="js-nav__live-tv nav__live-tv" id="nav-mobileTV"', 'Live TV ']
# False False
# ['i class="nav__live-tv-icon"', '']
# False False
# ['/i', '']
# False False
# ['/a', '']
# False False
# ['form id="search-form" class="search__form" method="get" action="/search/" name="headerSearch"', '']
# False False
# ['div class="search__form-fields"', '']
# False False
# ['input class="search__input-field" type="text" placeholder="Search CNN..." id="search-input-field" name="q"', '']
# False False
# ['button id="submit-button" class="search__submit-button"', 'Search &raquo;']
# False False
# ['/button', '']
# False False
# ['/div', '']
# False False
# ['div id="search-button" class="search__button" type="button" role="button"', '']
# False False
# ['/div', '']
# False False
# ['/form', '']
# False False
# ['div class="js-edition-picker edition-picker"', '']
# False False
# ['div class="edition-picker__current-edition"', 'International  Edition']
# False False
# ["span class='nav-section__expand-icon'", '+']
# False False
# ['/span', '']
# False False
# ['/div', '']
# False False
# ['div class="js-nav-editions edition-picker__unabridged" data-location="header" data-analytics="edition-picker"', '']
# False False
# ['div class="edition-picker__list"', '']
# False False
# ['div class="js-edition-item edition-picker__list-item" data-type="www" data-value="http://us.cnn.com"', 'U.S.']
# False False
# ['/div', '']
# False False
# ['div class="js-edition-item edition-picker__list-item" data-type="edition" data-value="http://edition.cnn.com"', 'International']
# False False
# ['/div', '']
# False False
# ['div class="js-edition-item edition-picker__list-item" data-value="http://arabic.cnn.com"', 'Arabic']
# False False
# ['/div', '']
# False False
# ['div class="js-edition-item edition-picker__list-item" data-value="http://cnnespanol.cnn.com/"', 'Español']
# False False
# ['/div', '']
# False False
# ['/div', '']
# False False
# ['form class="edition-picker__radio-buttons" data-location="header" data-analytics="edition-picker"', '']
# False False
# ['p class="edition-picker__radio-button-label" ', 'Set edition preference:']
# False False
# ['/p', '']
# False False
# ['label class="edition-picker__radio-button"', '']
# False False
# ['input type="radio" class="js-edition-option edition_domestic" name="nav-edition" data-type="www" data-value="http://us.cnn.com"/', '']
# False False
# ['span for="edition_domestic"', 'U.S.']
# False False
# ['/span', '']
# False False
# ['/label', '']
# False False
# ['label class="edition-picker__radio-button"', '']
# False False
# ['input type="radio" class="js-edition-option edition_international" name="nav-edition" data-type="edition" data-value="http://edition.cnn.com"/', '']
# False False
# ['span for="edition_international"', 'International']
# False False
# ['/span', '']
# False False
# ['/label', '']
# False False
# ['button class="js-edition-confirm edition-picker__confirm-button"', 'Confirm']
# False False
# ['/button', '']
# False False
# ['/form', '']
# False False
# ['/div', '']
# False False
# ['/div', '']
# False False
# ['div id="menu" class="nav-menu js-navigation-hamburger"', '']
# False False
# ['div class="nav-menu__hamburger"', '']
# False False
# ['/div', '']
# False False
# ['/div', '']
# False False
# ['/div', '']
# False False
# ['/div', '']
# False False
# ['div id="nav-expanded" class="nav-flyout"', '']
# False False
# ['div class="js-edition-picker edition-picker"', '']
# False False
# ['div class="edition-picker__current-edition"', 'International  Edition']
# False False
# ["span class='nav-section__expand-icon'", '+']
# False False
# ['/span', '']
# False False
# ['/div', '']
# False False
# ['div class="js-nav-editions edition-picker__unabridged" data-location="header" data-analytics="edition-picker"', '']
# False False
# ['div class="edition-picker__list"', '']
# False False
# ['div class="js-edition-item edition-picker__list-item" data-type="www" data-value="http://us.cnn.com"', 'U.S.']
# False False
# ['/div', '']
# False False
# ['div class="js-edition-item edition-picker__list-item" data-type="edition" data-value="http://edition.cnn.com"', 'International']
# False False
# ['/div', '']
# False False
# ['div class="js-edition-item edition-picker__list-item" data-value="http://arabic.cnn.com"', 'Arabic']
# False False
# ['/div', '']
# False False
# ['div class="js-edition-item edition-picker__list-item" data-value="http://cnnespanol.cnn.com/"', 'Español']
# False False
# ['/div', '']
# False False
# ['/div', '']
# False False
# ['form class="edition-picker__radio-buttons" data-location="header" data-analytics="edition-picker"', '']
# False False
# ['p class="edition-picker__radio-button-label" ', 'Set edition preference:']
# False False
# ['/p', '']
# False False
# ['label class="edition-picker__radio-button"', '']
# False False
# ['input type="radio" class="js-edition-option edition_domestic" name="nav-edition" data-type="www" data-value="http://us.cnn.com"/', '']
# False False
# ['span for="edition_domestic"', 'U.S.']
# False False
# ['/span', '']
# False False
# ['/label', '']
# False False
# ['label class="edition-picker__radio-button"', '']
# False False
# ['input type="radio" class="js-edition-option edition_international" name="nav-edition" data-type="edition" data-value="http://edition.cnn.com"/', '']
# False False
# ['span for="edition_international"', 'International']
# False False
# ['/span', '']
# False False
# ['/label', '']
# False False
# ['button class="js-edition-confirm edition-picker__confirm-button"', 'Confirm']
# False False
# ['/button', '']
# False False
# ['/form', '']
# False False
# ['/div', '']
# False False
# ['/div', '']
# False False
# ['div id="nav-expanded-menu" class="nav-flyout__container"', '']
# False False
# ['div class="nav-flyout__menu-item nav-flyout__menu-item--intl_homepage" data-analytics-header="flyout-menu_intl_homepage"', '']
# False False
# ['a class="nav-flyout__section-title" href="/"', 'Home']
# False False
# ['/a', '']
# False False
# ['ul class="nav-flyout__submenu"', '']
# False False
# ['/ul', '']
# False False
# ['/div', '']
# False False
# ['div class="nav-flyout__menu-item nav-flyout__menu-item--intl_regions" data-analytics-header="flyout-menu_intl_regions"', '']
# False False
# ['a class="nav-flyout__section-title" href="/regions"', 'Regions']
# False False
# ['/a', '']
# False False
# ['ul class="nav-flyout__submenu"', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_U.S."', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/us"', 'U.S.']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Africa"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/africa"', 'Africa']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Americas"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/americas"', 'Americas']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Asia"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/asia"', 'Asia']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_China"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/china"', 'China']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Europe"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/europe"', 'Europe']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Middle East"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/middle-east"', 'Middle East']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Opinion"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/opinions"', 'Opinion']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['/ul', '']
# False False
# ['/div', '']
# False False
# ['div class="nav-flyout__menu-item nav-flyout__menu-item--politics" data-analytics-header="flyout-menu_politics"', '']
# False False
# ['a class="nav-flyout__section-title" href="/politics"', 'U.S. Politics']
# False False
# ['/a', '']
# False False
# ['ul class="nav-flyout__submenu"', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_45"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/politics/president-donald-trump-45"', '45']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Congress"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/politics/congress-capitol-hill"', 'Congress']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Security"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/politics/us-security"', 'Security']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_The Nine"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/politics/supreme-court-nine"', 'The Nine']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Trumpmerica"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/politics/trumpmerica"', 'Trumpmerica']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_State"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/politics/state-cnn-politics-magazine"', 'State']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['/ul', '']
# False False
# ['/div', '']
# False False
# ['div class="nav-flyout__menu-item nav-flyout__menu-item--money" data-analytics-header="flyout-menu_money"', '']
# False False
# ['a class="nav-flyout__section-title" href="http://money.cnn.com/INTERNATIONAL/"', '']
# False False
# ['img src="//cdn.cnn.com/cnn/.e1mo/img/4.0/logos/menu_money.png" class="nav-menu__img-money" style="width: 78.6px;"', '']
# False False
# ['/a', '']
# False False
# ['ul class="nav-flyout__submenu"', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Business"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="http://money.cnn.com/news/"', 'Business']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Markets"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="http://money.cnn.com/data/markets/"', 'Markets']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Tech"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="http://money.cnn.com/technology/"', 'Tech']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Luxury"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="http://money.cnn.com/luxury/"', 'Luxury']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['/ul', '']
# False False
# ['/div', '']
# False False
# ['div class="nav-flyout__menu-item nav-flyout__menu-item--entertainment" data-analytics-header="flyout-menu_entertainment"', '']
# False False
# ['a class="nav-flyout__section-title" href="/entertainment"', '']
# False False
# ['img src="//cdn.cnn.com/cnn/.e1mo/img/4.0/logos/menu_entertainment.png" class="nav-menu__img-entertainment" style="width: 132.5px;"', '']
# False False
# ['/a', '']
# False False
# ['ul class="nav-flyout__submenu"', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Stars"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/entertainment/celebrities"', 'Stars']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Screen"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/entertainment/movies"', 'Screen']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Binge"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/entertainment/tv-shows"', 'Binge']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Culture"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/entertainment/culture"', 'Culture']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Media"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="http://money.cnn.com/media"', 'Media']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['/ul', '']
# False False
# ['/div', '']
# False False
# ['div class="nav-flyout__menu-item nav-flyout__menu-item--tech" data-analytics-header="flyout-menu_tech"', '']
# False False
# ['a class="nav-flyout__section-title" href="http://money.cnn.com/technology/"', '']
# False False
# ['img src="//cdn.cnn.com/cnn/.e1mo/img/4.0/logos/menu_tech.png" class="nav-menu__img-tech" style="width: 43.25px;"', '']
# False False
# ['/a', '']
# False False
# ['ul class="nav-flyout__submenu"', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Business"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="http://money.cnn.com/technology/business/"', 'Business']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Culture"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="http://money.cnn.com/technology/culture/"', 'Culture']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Gadgets"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="http://money.cnn.com/technology/gadgets/"', 'Gadgets']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Future"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="http://money.cnn.com/technology/future/"', 'Future']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Startups"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="http://money.cnn.com/technology/startups/"', 'Startups']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['/ul', '']
# False False
# ['/div', '']
# False False
# ['div class="nav-flyout__menu-item nav-flyout__menu-item--sport" data-analytics-header="flyout-menu_sport"', '']
# False False
# ['a class="nav-flyout__section-title" href="/sport"', 'Sport']
# False False
# ['/a', '']
# False False
# ['ul class="nav-flyout__submenu"', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Football"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/sport/football"', 'Football']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Tennis"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/sport/tennis"', 'Tennis']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Equestrian"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/sport/equestrian"', 'Equestrian']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Golf"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/sport/golf"', 'Golf']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Judo"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/sport/judo-world"', 'Judo']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Horse Racing"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/sport/horse-racing"', 'Horse Racing']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Motorsport"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/sport/motorsport"', 'Motorsport']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Sailing"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/sport/sailing"', 'Sailing']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Skiing"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/sport/skiing"', 'Skiing']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Olympics"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/sport/winter-olympics-2018"', 'Olympics']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['/ul', '']
# False False
# ['/div', '']
# False False
# ['div class="nav-flyout__menu-item nav-flyout__menu-item--intl_travel" data-analytics-header="flyout-menu_intl_travel"', '']
# False False
# ['a class="nav-flyout__section-title" href="/travel"', '']
# False False
# ['img src="//cdn.cnn.com/cnn/.e1mo/img/4.0/logos/menu_travel.png" class="nav-menu__img-travel" style="width: 57px;"', '']
# False False
# ['/a', '']
# False False
# ['ul class="nav-flyout__submenu"', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Destinations"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/travel/destinations"', 'Destinations']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Food &amp; Drink"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/travel/food-and-drink"', 'Food &amp; Drink']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Play"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/travel/play"', 'Play']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Stay"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/travel/stay"', 'Stay']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Videos"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/travel/videos"', 'Videos']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['/ul', '']
# False False
# ['/div', '']
# False False
# ['div class="nav-flyout__menu-item nav-flyout__menu-item--style" data-analytics-header="flyout-menu_style"', '']
# False False
# ['a class="nav-flyout__section-title" href="/style"', '']
# False False
# ['img src="//cdn.cnn.com/cnn/.e1mo/img/4.0/logos/menu_style_new.png" class="nav-menu__img-style" style="width: 63px;"', '']
# False False
# ['/a', '']
# False False
# ['ul class="nav-flyout__submenu"', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Arts"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/style/arts"', 'Arts']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Design"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/style/design"', 'Design']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Fashion"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/style/fashion"', 'Fashion']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Architecture"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/style/architecture"', 'Architecture']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Luxury"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/style/luxury"', 'Luxury']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Autos"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/style/autos"', 'Autos']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Video"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/style/videos"', 'Video']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['/ul', '']
# False False
# ['/div', '']
# False False
# ['div class="nav-flyout__menu-item nav-flyout__menu-item--health" data-analytics-header="flyout-menu_health"', '']
# False False
# ['a class="nav-flyout__section-title" href="/health"', 'Health']
# False False
# ['/a', '']
# False False
# ['ul class="nav-flyout__submenu"', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Diet + Fitness"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/health/diet-fitness"', 'Diet + Fitness']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Living Well"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/health/living-well"', 'Living Well']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Parenting + Family"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/living/cnn-parents"', 'Parenting + Family']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Vital Signs"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/health/vital-signs"', 'Vital Signs']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['/ul', '']
# False False
# ['/div', '']
# False False
# ['div class="nav-flyout__menu-item nav-flyout__menu-item--features" data-analytics-header="flyout-menu_features"', '']
# False False
# ['a class="nav-flyout__section-title" href="/specials"', 'Features']
# False False
# ['/a', '']
# False False
# ['ul class="nav-flyout__submenu"', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Freedom Project"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/world/freedom-project"', 'Freedom Project']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Impact Your World"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/impact-your-world"', 'Impact Your World']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Inside Africa"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/africa/inside-africa"', 'Inside Africa']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_2 degrees"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/opinions/two-degrees"', '2 degrees']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_CNN Heroes"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/cnn-heroes"', 'CNN Heroes']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_All Features"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials"', 'All Features']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['/ul', '']
# False False
# ['/div', '']
# False False
# ['div class="nav-flyout__menu-item nav-flyout__menu-item--intl_videos" data-analytics-header="flyout-menu_intl_videos"', '']
# False False
# ['a class="nav-flyout__section-title" href="/videos"', 'Video']
# False False
# ['/a', '']
# False False
# ['ul class="nav-flyout__submenu"', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Video news"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/latest-news-videos"', 'Video news']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Feature shows"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/international-video-landing/feature-show-videos"', 'Feature shows']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_HLN"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/videos/hln"', 'HLN']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_TV shows"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/tv/shows"', 'TV shows']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_TV schedule"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/tv/schedule/europe"', 'TV schedule']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Faces of CNN Worldwide"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/tv/anchors-and-reporters"', 'Faces of CNN Worldwide']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_CNNVR"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/vr"', 'CNNVR']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['/ul', '']
# False False
# ['/div', '']
# False False
# ['div class="nav-flyout__menu-item nav-flyout__menu-item--vr" data-analytics-header="flyout-menu_vr"', '']
# False False
# ['a class="nav-flyout__section-title" href="/vr"', '']
# False False
# ['img src="//cdn.cnn.com/cnn/.e1mo/img/4.0/vr/vr_new_asset.png" class="nav-menu__img-vr360" style="width: 55px;"', '']
# False False
# ['/a', '']
# False False
# ['ul class="nav-flyout__submenu"', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_How To Watch VR"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/2017/03/04/vr/how-to-watch-vr"', 'How To Watch VR']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Archives"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/vr/vr-archives"', 'Archives']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['/ul', '']
# False False
# ['/div', '']
# False False
# ['div class="nav-flyout__menu-item nav-flyout__menu-item--intl_more" data-analytics-header="flyout-menu_intl_more"', '']
# False False
# ['a class="nav-flyout__section-title" href="/more"', 'More…']
# False False
# ['/a', '']
# False False
# ['ul class="nav-flyout__submenu"', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Weather"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/weather"', 'Weather']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_CNN Profiles"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/profiles"', 'CNN Profiles']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Leadership"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/more/cnn-leadership"', 'Leadership']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Pressroom"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="//cnnpressroom.blogs.cnn.com/"', 'Pressroom']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Partner sites"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/world/specials-page-cnn-partners"', 'Partner sites']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_iReport"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="/specials/opinions/cnnireport"', 'iReport']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['li class="nav-flyout__submenu-item" data-analytics-header="flyout-submenu_Work for CNN"', '']
# False False
# ['a class="nav-flyout__submenu-link" href="https://www.turnerjobs.com/search-jobs?orgIds=1174&ac=19299"', 'Work for CNN']
# False False
# ['/a', '']
# False False
# ['/li', '']
# False False
# ['/ul', '']
# False False
# ['/div', '']
# False False
# ['/div', '']
# False False
# ['div class="nav-flyout-footer" data-location="header" data-analytics="edition-picker"', '']
# False False
# ['div class="nav-flyout-footer__edition-list"', '']
# False False
# ['div id="bottom-us-edition" class="js-nav-flyout-footer-edition-list-item nav-flyout-footer__edition-list-item nav-flyout-footer__edition-list-item--us" data-type="www" data-value="http://us.cnn.com"', '']
# False False
# ['img class="nav-flyout-footer__edition-icon" src="//cdn.cnn.com/cnn/.e1mo/img/4.0/logos/logo_cnn_nav_bottom.png"/', 'U.S.']
# False False
# ['/div', '']
# False False
# ['div id="bottom-intl-edition" class="js-nav-flyout-footer-edition-list-item nav-flyout-footer__edition-list-item nav-flyout-footer__edition-list-item--intl" data-type="edition" data-value="http://edition.cnn.com"', '']
# False False
# ['img class="nav-flyout-footer__edition-icon" src="//cdn.cnn.com/cnn/.e1mo/img/4.0/logos/logo_cnn_nav_bottom.png"/', 'International']
# False False
# ['/div', '']
# False False
# ['div class="js-nav-flyout-footer-edition-list-item nav-flyout-footer__edition-list-item" data-value="http://cnnespanol.cnn.com/"', '']
# False False
# ['img class="nav-flyout-footer__edition-icon" src="//cdn.cnn.com/cnn/.e1mo/img/4.0/logos/logo_cnn_espaniol.png"/', 'Espa&ntilde;ol']
# False False
# ['/div', '']
# False False
# ['div class="js-nav-flyout-footer-edition-list-item nav-flyout-footer__edition-list-item" data-value="http://arabic.cnn.com"', '']
# False False
# ['img class="nav-flyout-footer__edition-icon" src="//cdn.cnn.com/cnn/.e1mo/img/4.0/logos/logo_cnn_arabic.png"/', 'Arabic']
# False False
# ['/div', '']
# False False
# ['/div', '']
# False False
# ...
# ['/div', '\n    \n    ']
# False False
# ['div class="c-compact-river__entry "', '\n      ']
# False False
# ['div class="c-entry-box--compact c-entry-box--compact--stream" data-chorus-optimize-id="16432951" data-chorus-optimize-module="entry-box" data-analytics-placement="river:39"', '\n  \n    ']
# False False
# ['a href="https://www.theverge.com/2017/11/16/16668910/tesla-event-news-electric-semi-truck-elon-musk" class="c-entry-box--compact__image-wrapper"  data-analytics-link="stream:image"', '\n      \n        ']
# False False
# ['div class="c-entry-box--compact__image"', '\n          \n']
# False False
# ['img class="c-dynamic-image " src="..." alt="" data-chorus-optimize-field="main_image" data-cid="site/dynamic_size_image-1511103608_1506_51642" data-cdata=\'{"image_id":57642027,"ratio":"*"}\'', '\n']
# False False
# ['noscript', '']
# False False
# ['img src="https://cdn.vox-cdn.com/uploads/chorus_image/image/57642027/Semi_Front_78.1510894138.jpg" alt=""', '']
# False False
# ['/noscript', '\n\n        ']
# False False
# ['/div', '\n      \n      \n      \n    ']
# False False
# ['/a', '\n  \n  ']
# False False
# ['div class="c-entry-box--compact__body"', '\n    \n    \n      ']
# False False
# ['ul class="c-entry-box--compact__labels"', '\n      \n        \n      \n      \n      \n        ']
# False False
# ['li class="c-entry-box--compact__label-storystream"', '\n          ']
# False False
# ['svg', '']
# False False
# ['use xlink:href="#icon-clock"', '']
# False False
# ['/use', '']
# False False
# ['/svg', '\n          ']
# False False
# ['span', '12 Updates']
# False False
# ['a href="https://www.theverge.com/2017/11/16/16668910/tesla-event-news-electric-semi-truck-elon-musk"', 'View All']
# False False
# ['/a', '']
# False False
# ['/span', '\n        ']
# False False
# ['/li', '\n      \n      \n      \n      ']
# False False
# ['/ul', '\n    \n    \n    ']
# False False
# ['h2 class="c-entry-box--compact__title"', '']
# False False
# ['a data-chorus-optimize-field="hed" data-analytics-link="stream" href="https://www.theverge.com/2017/11/16/16668910/tesla-event-news-electric-semi-truck-elon-musk"', 'All of the news from Tesla’s electric semi truck event']
# False False
# ['/a', '']
# False False
# ['/h2', '\n    \n    \n      \n        ']
# False False
# ['div class="c-byline" data-cid="site/byline-1511103608_1817_51644" data-cdata=\'{"timestamp":1510894139}\'', '\n  \n    by\n    ']
# False False
# ['span class="c-byline__item"', '\n      \n        Verge Staff\n      \n    ']
# False False
# ['/span', '\n    \n      ']
# False False
# ['time class="c-byline__item" data-ui="timestamp" data-relative-timestamp="true"', '\n        November 16\n      ']
# False False
# ['/time', '\n    \n    \n    \n  \n  \n  \n  ']
# False False
# ['a data-entry-admin="16432951" data-cid="tools/entry_admin_button-1511103608_2934_51643" data-cdata=\'{"id":16432951}\'', '']
# False False
# ['/a', '\n\n']
# False False
# ['/div', '\n\n      \n    \n    \n    \n\n    \n    \n  ']
# False False
# ['/div', '\n\n  \n\n  \n']
# False False
# ['/div', '\n\n    ']
# False False
# ['/div', '\n    \n  \n  \n']
# False False
# ['/div', '\n\n        ']
# False False
# ['/div', '\n          ']
# False False
# ['div class="l-col__sidebar" data-analytics-placement="sidebar"', '\n            ']
# False False
# ['div class="u-desktop-only"', '\n            ']
# False False
# ['/div', '\n          ']
# False False
# ['/div', '\n      ']
# False False
# ['/div', '\n          ']
# False False
# ['div class="c-pagination u-clearfix"', '\n  ']
# False False
# ['div class="c-pagination__wrap"', '\n    \n      ']
# False False
# ['a class="c-pagination__more c-pagination__link p-button" href="https://www.theverge.com/archives"', 'More Stories']
# False False
# ['/a', '\n    \n  ']
# False False
# ['/div', '\n']
# False False
# ['/div', '\n\n    ']
# False False
# ['/div', '\n  ']
# False False
# ['/div', '\n\n\n\n']
# False False
# ['div class="l-wrapper"', '\n  \n']
# False False
# ['/div', '\n\n    ']
# False False
# ['footer class="c-footer" role="contentinfo"', '\n  ']
# False False
# ['div class="l-wrapper c-footer__wrapper"', '\n    ']
# False False
# ['div class="c-footer__section c-footer__section-logo"', '\n      ']
# False False
# ['a rel="nofollow" href="/" class="c-footer__logo-link"', '\n        \n          \n  ']
# False False
# ['svg fill="#fff" xmlns="http://www.w3.org/2000/svg" viewBox="0 291.4 1280 217.2"', '']
# False False
# ['path d="M0 292.1v58.1h39.7v153.2h67.1V292.1M220.1 372.4h-31.4v-22.3h15.8v-58h-82.8v211.3h67v-79.9h31.4v79.9h67.2V292.1h-67.2M302 503.4h124.3v-58.2h-60.2v-24.6h38.3v-48.2h-38.3v-22.2h60.2v-58.1H302M954.8 363.6c0-45.6-33.7-71.5-81.5-71.5h-74.7v211.2h67.1v-54.1l38.4 54.1h75.7l-54.4-81c19.6-10.7 29.4-30.2 29.4-58.7M865.5 387v-39.3c9.3 0 20.7 2.8 24.1 13 .3.9.5 1.9.8 2.9 0 .1 0 .3.1.4.1 1 .3 2.2.3 3.4 0 15.7-14.3 19.6-25.3 19.6M559.2 420.8h-.6l-4.8-17.4-15-53.1h26.4l17.4-58.2h-134l76.8 211.2h68.8l8.3-22.6s36.8-99.8 56.9-154.2v176.8h124.3v-58.2h-60.2v-24.6h38.2v-48.1h-38.2v-22.2h60.2V292H598l-38.8 128.8zM1280 350.3v-58.1h-124.3v211.2H1280v-58.2h-60.3v-24.6h38.3v-48h-38.3v-22.3"/', '']
# False False
# ['path d="M1142.8 459.1V373H1048v48h35.3v17.1c-2.7 2.4-8.5 3.7-14.5 3.7-24.6 0-42.8-19.4-42.8-43.1s17.7-44.7 42.3-44.7c14.9 0 50.2.1 50.2.1v-62.6h-16.1c-30 0-59.9-2.4-87.4 11.8-21.7 11.2-38.9 30.2-48 52.8-5.3 13.3-8 27.7-8 42 0 59.9 47 110.4 107.9 110.4 30.2 0 59.7-11.3 75.8-25.4.1-14.6.1-16.8.1-24"/', '']
# False False
# ['/svg', '\n\n\n        \n        ']
# False False
# ['span class="u-hidden-text"', 'Chorus']
# False False
# ['/span', '\n      ']
# False False
# ['/a', '\n    ']
# False False
# ['/div', '\n\n    ']
# False False
# ['div class="c-footer__section c-footer__section-links"', '\n      ']
# False False
# ['ul class="u-list-dot-sep"', '\n        \n          ']
# False False
# ['li', '']
# False False
# ['a rel="nofollow" href="https://www.voxmedia.com/terms-of-use"', 'Terms of Use']
# False False
# ['/a', '']
# False False
# ['/li', '\n        \n          ']
# False False
# ['li', '']
# False False
# ['a rel="nofollow" href="https://www.voxmedia.com/privacy-policy"', 'Privacy Policy']
# False False
# ['/a', '']
# False False
# ['/li', '\n        \n          ']
# False False
# ['li', '']
# False False
# ['a rel="nofollow" href="https://www.voxmedia.com/communications-preferences"', 'Communications Preferences']
# False False
# ['/a', '']
# False False
# ['/li', '\n        \n      ']
# False False
# ['/ul', '\n      ']
# False False
# ['ul class="u-list-dot-sep"', '\n        \n          ']
# False False
# ['li', '']
# False False
# ['a rel="nofollow" href="/contact-the-verge"', 'Contact']
# False False
# ['/a', '']
# False False
# ['/li', '\n        \n          ']
# False False
# ['li', '']
# False False
# ['a rel="nofollow" href="https://apps.voxmedia.com/verge-tips/"', 'Tip Us']
# False False
# ['/a', '']
# False False
# ['/li', '\n        \n          ']
# False False
# ['li', '']
# False False
# ['a rel="nofollow" href="/community-guidelines"', 'Community Guidelines']
# False False
# ['/a', '']
# False False
# ['/li', '\n        \n          ']
# False False
# ['li', '']
# False False
# ['a rel="nofollow" href="/about-the-verge"', 'About']
# False False
# ['/a', '']
# False False
# ['/li', '\n        \n          ']
# False False
# ['li', '']
# False False
# ['a rel="nofollow" href="/ethics-statement"', 'Ethics Statement']
# False False
# ['/a', '']
# False False
# ['/li', '\n        \n      ']
# False False
# ['/ul', '\n\n      \n\n      ']
# False False
# ['div class="c-footer__status"', '\n        ']
# False False
# ['span id="status_io" class="m-footer__bottom__status"', '\n  All Systems Operational\n  ']
# False False
# ['a href="http://status.voxmedia.com" rel="nofollow" target="_blank"', 'Check out our status page for more details.']
# False False
# ['/a', '\n']
# False False
# ['/span', '\n\n      ']
# False False
# ['/div', '\n    ']
# False False
# ['/div', '\n\n    ']
# False False
# ['div class="c-footer__section c-footer__section-vox"', '\n      ']
# False False
# ['a rel="nofollow" class="u-block" href="http://www.voxmedia.com"', '']
# False False
# ['span class="u-hidden-text"', 'Vox Media']
# False False
# ['/span', '']
# False False
# ['svg id="Layer_1" xmlns="http://www.w3.org/2000/svg" viewbox="-147 464.2 484 79.5" class="c-footer__vox-logo"', '']
# False False
# ['g', '']
# False False
# ['path fill="#4E4E50" class="vox-media-logo-text" d="M-133.2 498l9.9 29 6.4-19.2c1.1-3.3 2.1-6.6 3-9.4h13.3l-13.2 32.4c-2.1 5.3-3.4 8.4-4.6 12l-10 .6-13.2-32c-1.6-4-3.6-9-5.4-12.9l13.8-.5zm38.8 23.6c0-14 9.3-24.4 23.2-24.4 13.3 0 22.1 9.8 22.1 22.1 0 14-9.4 24.4-23.2 24.4-13.4.1-22.1-9.8-22.1-22.1zm33-.9c0-8.4-4.3-13.6-10.3-13.6-6.4 0-10.5 6-10.5 13.2 0 8.4 4.3 13.6 10.3 13.6 6.4 0 10.5-6 10.5-13.2zm19.2 21.9l15.3-22.7-6-8.8-8.6-12.7 13.9-.5 9.1 14.2 3.1-5.3c1.6-2.6 3.8-6.1 5.4-8.6H3.7l-14.6 21.9 5.4 7.9c2.5 3.8 6.8 10.3 9.6 14.4l-14 .5-9.3-15.1-2.9 4.7c-1.4 2.3-4.4 7.2-6.1 9.8h-14v.3zm79.4-15.2l1.9-13.9c.6-4 1.6-12 1.8-15.3l9.6-.4c1.1 2.5 2.7 6.1 4 8.9l8.2 18.2 8-18.5c1.2-2.7 2.6-6 3.7-8.5h9.3c.4 3.7 1.4 11.5 2 15.6l2 13.9c.6 4.1 1.8 11.9 2.5 15.2l-12.4.5c-.1-1.8-.7-7.1-1.1-9.6l-1.8-14c-3.1 7.7-8.6 21.4-9.4 23.6l-6.6.3-9.5-23.3-1.5 13.5c-.3 2.5-.8 7.3-.8 9.1H34.7c.7-3.3 1.9-11.2 2.5-15.3zm96.1 15.5c-4.2-.3-9.3-.3-14.2-.3-5.5 0-11.5.1-16.2.3.3-3 .4-11.3.4-15.4v-14c0-4-.1-12.5-.4-15.6 4.6.2 9.6.3 15.3.3 5.2 0 10-.1 14.3-.3-.3 3.1-.5 6.2-.5 10-3.2-.1-6.4-.1-10.3-.1-1.9 0-4 0-5.8.1-.1.9-.1 2.2-.1 2.8v4.9l13.7-.1c-.1 2.6-.2 5.5-.2 8.8h-13.5v5.7c0 .7 0 2 .1 2.9 1.8 0 3.9.1 5.8.1 4.5 0 8.3-.1 12-.2-.2 3.2-.4 6.2-.4 10.1zm30-.3h-16.6c.3-3 .4-11.1.4-15.2v-13.9c0-4-.1-12-.4-15.1 2.3 0 7.9-.4 14.9-.4 16.7 0 26 8 26 21.5 0 14.2-9.5 23.1-24.3 23.1zm-.2-35c-1.3 0-2.1.1-3.1.2-.1.8-.1 2.1-.1 2.8v19.6c0 .8 0 1.7.1 2.6 1 .1 1.8.2 3.3.2 8.4 0 12-5.5 12-13-.1-7.9-4.7-12.4-12.2-12.4zm37.2 35c.3-3 .4-11.1.4-15.2v-13.9c0-4-.1-12.2-.4-15.2 2.5 0 11.3-.1 13.4-.3-.2 1.8-.3 6.9-.3 9.3v26.2c0 2.4.1 7.3.3 9.1h-13.4zm38.1-32.2c2.2-5.2 3.7-8.5 4.9-12l10.1-.6 13.8 32c1.6 3.9 4 9 5.8 12.9l-13.4.5-3.4-8.4h-15.4c-.8 2.1-2.6 7.1-3 7.9h-13.1l13.7-32.3zm4.9 16.5h10.1l-5.1-13.7-5 13.7z"', '']
# False False
# ['/path', '']
# False False
# ['path fill="#F6A01A" d="M337 464.2V498l-30-16.9 30-16.9z"', '']
# False False
# ['/path', '']
# False False
# ['path fill="#FBE346" d="M276.9 464.2V498l30.1-16.9-30.1-16.9z"', '']
# False False
# ['/path', '']
# False False
# ['path fill="#F47B20" d="M307 481.1V515l30-17-30-16.9z"', '']
# False False
# ['/path', '']
# False False
# ['path fill="#F8CC15" d="M307 481.1V515l-30.1-17 30.1-16.9z"', '']
# False False
# ['/path', '']
# False False
# ['/g', '']
# False False
# ['/svg', '']
# False False
# ['/a', '\n      \n        ']
# False False
# ['a rel="nofollow" class="u-block c-footer__corporate-link" href="https://www.voxmedia.com/vox-advertising"', 'Advertise with us']
# False False
# ['/a', '\n      \n        ']
# False False
# ['a rel="nofollow" class="u-block c-footer__corporate-link" href="https://jobs.voxmedia.com"', 'Jobs @ Vox Media']
# False False
# ['/a', '\n      \n      &copy; 2017 ']
# False False
# ['a rel="nofollow" href="http://www.voxmedia.com"', 'Vox Media']
# False False
# ['/a', ', Inc. All Rights Reserved\n      \n      \n    ']
# False False
# ['/div', '\n  ']
# False False
# ['/div', '\n']
# False False
# ['/footer', '\n\n    \n  ']
# False False
# ['/div', '\n\n    ']
# False False
# ['script src="https://cdn.vox-cdn.com/javascripts/unison_body.vb0def62dca980774.js"', '']
# True False
# ['/script', '\n      ']
# False False
# ['script src="https://cdn.vox-cdn.com/presto/chorus.13af518e208d5a990a46.js"', '']
# True False
# ['/script', '\n  \n\n      ']
# False False
# ['!-- Phonograph --', '\n  ']
# False False
# ['script src="https://phonograph2.voxmedia.com/pickup.js" async="async" defer="defer"', '']
# True False
# ['/script', '\n  ']
# False False
# ['script', '\n//']
# True False
# ["![CDATA[\n\n          var phonographEvents = phonographEvents || [];\n          if (window.dataLayer && window.Context) {\n            Context.fetch().then(function() {\n              var data = {'Page Title': document.title, 'GA Track Prefix': 't1.', 'User ID': Context.currentUser.get('id') || null};\n              for (var i=0; i "]
# [" dataLayer.length; i++) {\n                if (dataLayer[i]['Network']) {\n                  Object.keys(dataLayer[i]).forEach(function(k) { data[k] = dataLayer[i][k]; });\n                  break;\n                }\n              }\n              phonographEvents.push(['pageload', data]);\n            });\n          } else {\n            phonographEvents.push(['pageload', {'Page Title': document.title}]);\n          }\n        \n//]]", '\n']
# True False
# ['/script', '\n  ']
# False False
# ['!-- End Phonograph --', '\n\n    \n  ']
# False False
# ['/body', '\n']
# False False
# ['/html', '\n\n']
# False False
# november 35
# comments 23
# tesla 12
# andrew 8
# semi 6
# roadster 5
# review 5
# verge 5
# tech 4
# paul 4
# vox 4
# hawkins 4
# media 4
# science 4
# backflip 4
# miller 4
# grush 3
# culture 3
# jacob 3
# breaker 3
# reviews 3
# loren 3
# phones 3
# ong 3
# thuy 3
# kastrenakes 3
# friday 3
# circuit 3
# iphone 3
# truck 3
# comment 3
# black 3
# watch 3
# cars 3
# lenovo 2
# chen 2
# zac 2
# garun 2
# try 2
# zte 2
# set 2
# ashley 2
# smart 2
# complement 2
# siri 2
# staff 2
# double 2
# battery 2
# combinator 2
# amazon 2
# microsoft 2
# misses 2
# trouble 2
# deal 2
# leaping 2
# chaim 2
# discounts 2
# humankind 2
# id 2
# portable 2
# natt 2
# virtual 2
# pixel 2
# axon 2
# micah 2
# singleton 2
# store 2
# reality 2
# sign 2
# forums 2
# thiel 2
# estrada 2
# smoke 2
# charging 2
# headphones 2
# event 2
# bag 2
# webster 2
# getting 2
# vr 2
# peter 2
# gartenberg 2
# film 2
# musk 2
# teaser 2
# angela 2
# life 2
# longform 2
# podcasts 2
# branded 2
# phone 2
# yoga 2
# video 2
# makeup 2
# elon 2
# log 2
# warren 2
# launch 2
# robot 2
# view 2
# giant 2
# people 2
# screen 2
# help 2
# apple 2
# carman 2
# google 2
# holiday 2
# speakerphone 1
# walmart 1
# menu 1
# future 1
# web 1
# mass 1
# unveils 1
# comfort 1
# plaugic 1
# rocket 1
# homepod 1
# living 1
# republic 1
# shape 1
# autonomy 1
# subsidies 1
# news 1
# hudson 1
# unveiling 1
# local 1
# shannon 1
# preordered 1
# deadpool 1
# amy 1
# forget 1
# internet 1
# guaranteed 1
# etienne 1
# jobs 1
# boston 1
# electric 1
# systems 1
# violence 1
# baby 1
# preferences 1
# repeatedly 1
# trademarked 1
# 5t 1
# android 1
# xbox 1
# copying 1
# affiliated 1
# brain 1
# superpowered 1
# robertson 1
# showers 1
# week 1
# dangers 1
# punisher 1
# stories 1
# acne 1
# dr 1
# fcc 1
# mysterious 1
# building 1
# health 1
# zombie 1
# imax 1
# month 1
# inc 1
# excellent 1
# weeks 1
# alessandra 1
# shut 1
# attempts 1
# tom 1
# liza 1
# communications 1
# policy 1
# details 1
# dynamics 1
# time 1
# border 1
# filmmaking 1
# community 1
# live 1
# grease 1
# sunday 1
# deals 1
# slow 1
# delayed 1
# hinges 1
# begins 1
# yes 1
# low 1
# page 1
# ties 1
# feel 1
# pixelbook 1
# trailers 1
# own 1
# guidelines 1
# version 1
# production 1
# date 1
# rights 1
# design 1
# removal 1
# distract 1
# wonderful 1
# mirror 1
# book 1
# marino 1
# continues 1
# supercut 1
# talent 1
# dogs 1
# tip 1
# maestros 1
# spacex 1
# polaroid 1
# toronto 1
# perform 1
# covered 1
# ride 1
# downfall 1
# gaming 1
# gift 1
# strange 1
# millions 1
# photography 1
# backflips 1
# chorus 1
# subscription 1
# buds 1
# cut 1
# incredibles 1
# related 1
# headsets 1
# scaling 1
# patients 1
# laura 1
# trucks 1
# football 1
# claim 1
# wasn 1
# income 1
# don 1
# paint 1
# bohn 1
# sharing 1
# solo 1
# apu 1
# clock 1
# missed 1
# status 1
# comics 1
# tiffany 1
# vlad 1
# chloe 1
# answer 1
# atlas 1
# orbit 1
# homes 1
# transportation 1
# moviepass 1
# dieter 1
# copy 1
# hardware 1
# journalist 1
# assistant 1
# sales 1
# theater 1
# music 1
# check 1
# scores 1
# smartwatches 1
# white 1
# lizzie 1
# rideables 1
# transit 1
# gross 1
# start 1
# potenza 1
# launches 1
# laptops 1
# kaitlyn 1
# wearing 1
# diagnose 1
# fujifilm 1
# broken 1
# ethics 1
# fate 1
# games 1
# simpsons 1
# steep 1
# reserved 1
# society 1
# tablets 1
# arcade 1
# zuma 1
# game 1
# trailer 1
# tv 1
# liptak 1
# statement 1
# app 1
# netflix 1
# nuts 1
# timely 1
# kids 1
# adi 1
# car 1
# virgin 1
# perfect 1
# tvs 1
# business 1
# postponed 1
# injury 1
# plan 1
# kondabolu 1
# aviation 1
# learned 1
# savov 1
# terms 1
# wall 1
# privacy 1
# satellites 1
# fastest 1
# quietly 1
# gun 1
# wireless 1
# scientists 1
# apps 1
# programming 1
# department 1
# teaches 1
# expansion 1
# ✕ 1
# guidebook 1
# operational 1
# space 1
# oneplus 1
# royalty 1
# racist 1
# musical 1
# released 1
# healthier 1
# cameras 1
# liao 1
# environment 1
# shoot 1
# oled 1
# tl 1
# troubleshoot 1
# create 1
# love 1
# hari 1
# tamara 1
# album 1
# arrow 1
# rolling 1
# shop 1
# hold 1
# stone 1
# opposites 1
# updates 1
# xiaomi 1
# model 1
# defense 1
# stefan 1
# lg 1
# re 1
# energy 1
# nightmare 1
# indefinitely 1
# reznikov 1
# guide 1
# home 1
# assigned 1
# maybe 1
# cold 1
# advertise 1
# coherent 1
# contact 1
# caricature 1
# begin 1
# sedaris 1
# question 1
# didn 1
